# %% [markdown]
# # _Physician Compare National_
#
# This notebook is a continuation from of my analysis on the following data gathered via [Data.Medicare.gov](https://data.medicare.gov/Physician-Compare/Physician-Compare-National-Downloadable-File/mj5m-pzi6). It contains general information about individual eligible professionals (EPs) such as demographic information and Medicare quality program participation. This dataset is updated twice a month with the most current demographic information available at that time.

# %%
# import pandas
import pandas as pd
pd.options.display.max_columns = None

# %%
# import CSV file with data
data = pd.read_csv('physician_compare_national.csv');

# %%
data.head()
# Out:
#           npi  ind_pac_id      ind_enrl_id     lst_nm  frst_nm mid_nm suff  \
# 0  1003000126  7517003643  I20130530000085  ENKESHAFI  ARDALAN    NaN  NaN
# 1  1003000126  7517003643  I20130530000085  ENKESHAFI  ARDALAN    NaN  NaN
# 2  1003000126  7517003643  I20150824000105  ENKESHAFI  ARDALAN    NaN  NaN
# 3  1003000126  7517003643  I20150824000105  ENKESHAFI  ARDALAN    NaN  NaN
# 4  1003000126  7517003643  I20150824000105  ENKESHAFI  ARDALAN    NaN  NaN
#
#   gndr cred med_sch  grd_yr           pri_spec sec_spec_1 sec_spec_2  \
# 0    M  NaN   OTHER  1994.0  INTERNAL MEDICINE        NaN        NaN
# 1    M  NaN   OTHER  1994.0  INTERNAL MEDICINE        NaN        NaN
# 2    M  NaN   OTHER  1994.0  INTERNAL MEDICINE        NaN        NaN
# 3    M  NaN   OTHER  1994.0  INTERNAL MEDICINE        NaN        NaN
# 4    M  NaN   OTHER  1994.0  INTERNAL MEDICINE        NaN        NaN
#
#   sec_spec_3 sec_spec_4 sec_spec_all                            org_lgl_nm  \
# 0        NaN        NaN          NaN   EMERGENCY MEDICINE ASSOCIATES PA PC
# 1        NaN        NaN          NaN   EMERGENCY MEDICINE ASSOCIATES PA PC
# 2        NaN        NaN          NaN   EMERGENCY MEDICINE ASSOCIATES PA PC
# 3        NaN        NaN          NaN  SOUTHEASTERN INTENSIVIST SERVICES PC
# 4        NaN        NaN          NaN  SOUTHEASTERN INTENSIVIST SERVICES PC
#
#      org_pac_id  num_org_mem                  adr_ln_1 adr_ln_2 ln_2_sprs  \
# 0  8.022915e+09        182.0        1850 TOWN CTR PKWY      NaN       NaN
# 1  8.022915e+09        182.0    1701 N GEORGE MASON DR      NaN       NaN
# 2  8.022915e+09        182.0  24440 STONE SPRINGS BLVD      NaN       NaN
# 3  9.335152e+09        133.0   1401 JOHNSTON WILLIS DR      NaN       NaN
# 4  9.335152e+09        133.0         411 W RANDOLPH RD      NaN       NaN
#
#                   cty  st        zip     phn_numbr hosp_afl_1  \
# 0              RESTON  VA  201903219  7.036899e+09     490112
# 1           ARLINGTON  VA  222053610  7.035586e+09     490112
# 2              DULLES  VA  201662247  5.713674e+09     490112
# 3  NORTH CHESTERFIELD  VA  232354730  8.044835e+09     490112
# 4            HOPEWELL  VA  238602938  8.045412e+09     490112
#
#        hosp_afl_lbn_1 hosp_afl_2                 hosp_afl_lbn_2 hosp_afl_3  \
# 0  CJW MEDICAL CENTER     210028  MEDSTAR SAINT MARY'S HOSPITAL        NaN
# 1  CJW MEDICAL CENTER     210028  MEDSTAR SAINT MARY'S HOSPITAL        NaN
# 2  CJW MEDICAL CENTER     210028  MEDSTAR SAINT MARY'S HOSPITAL        NaN
# 3  CJW MEDICAL CENTER     210028  MEDSTAR SAINT MARY'S HOSPITAL        NaN
# 4  CJW MEDICAL CENTER     210028  MEDSTAR SAINT MARY'S HOSPITAL        NaN
#
#   hosp_afl_lbn_3 hosp_afl_4 hosp_afl_lbn_4  hosp_afl_5 hosp_afl_lbn_5 assgn
# 0            NaN        NaN            NaN         NaN            NaN     Y
# 1            NaN        NaN            NaN         NaN            NaN     Y
# 2            NaN        NaN            NaN         NaN            NaN     Y
# 3            NaN        NaN            NaN         NaN            NaN     Y
# 4            NaN        NaN            NaN         NaN            NaN     Y

# %% [markdown]
# Looks like we need to correct the order of the columns, like we did in the previous notebook. After we update the column order, we'll then overwrite `physician_compare_national.csv` file to reflect this change so we won't have to again going forward.

# %%
# create list of columns in correct order 
correct_order = ['npi', 'ind_pac_id', 'ind_enrl_id', 'lst_nm', 'frst_nm', 'mid_nm', 'suff', 
                'gndr', 'cred', 'med_sch', 'grd_yr', 'pri_spec', 'sec_spec_1', 'sec_spec_2', 
                'sec_spec_3', 'sec_spec_4', 'sec_spec_all', 'org_lgl_nm', 'org_pac_id', 
                'num_org_mem', 'adr_ln_1', 'adr_ln_2', 'ln_2_sprs', 'cty', 'st', 'zip', 
                'phn_numbr', 'hosp_afl_1', 'hosp_afl_lbn_1', 'hosp_afl_2', 'hosp_afl_lbn_2', 
                'hosp_afl_3', 'hosp_afl_lbn_3', 'hosp_afl_4', 'hosp_afl_lbn_4', 'hosp_afl_5', 
                'hosp_afl_lbn_5', 'assgn']

# %%
# reorder columns to original format
data = data[correct_order]

# %%
# overwrite original CSV file to reflect correct order (only needed to run this first time through)
# data.to_csv('physician_compare_national.csv', index=False)

# %% [markdown]
# # _Diving Back into the Data!_
#
# Yesterday, we started by exploring the breakdown of physicians by state. However, I came to realize that this might be somewhat misleading as there appeared to be duplicate entries in the data (i.e. the same doctor was entered in multiple times). One of the variables though - `ind_enrl_id`, or the _Professional Enrollment ID_ - is a "unique ID for the individiaul professional enrollment that is the source for the data in the observation". This appears to be a better variable for identifying unique physicians versus the name. Let's see if this is in fact true or not with some exploration.

# %%
data.head()
# Out:
#           npi  ind_pac_id      ind_enrl_id     lst_nm  frst_nm mid_nm suff  \
# 0  1003000126  7517003643  I20130530000085  ENKESHAFI  ARDALAN    NaN  NaN
# 1  1003000126  7517003643  I20130530000085  ENKESHAFI  ARDALAN    NaN  NaN
# 2  1003000126  7517003643  I20150824000105  ENKESHAFI  ARDALAN    NaN  NaN
# 3  1003000126  7517003643  I20150824000105  ENKESHAFI  ARDALAN    NaN  NaN
# 4  1003000126  7517003643  I20150824000105  ENKESHAFI  ARDALAN    NaN  NaN
#
#   gndr cred med_sch  grd_yr           pri_spec sec_spec_1 sec_spec_2  \
# 0    M  NaN   OTHER  1994.0  INTERNAL MEDICINE        NaN        NaN
# 1    M  NaN   OTHER  1994.0  INTERNAL MEDICINE        NaN        NaN
# 2    M  NaN   OTHER  1994.0  INTERNAL MEDICINE        NaN        NaN
# 3    M  NaN   OTHER  1994.0  INTERNAL MEDICINE        NaN        NaN
# 4    M  NaN   OTHER  1994.0  INTERNAL MEDICINE        NaN        NaN
#
#   sec_spec_3 sec_spec_4 sec_spec_all                            org_lgl_nm  \
# 0        NaN        NaN          NaN   EMERGENCY MEDICINE ASSOCIATES PA PC
# 1        NaN        NaN          NaN   EMERGENCY MEDICINE ASSOCIATES PA PC
# 2        NaN        NaN          NaN   EMERGENCY MEDICINE ASSOCIATES PA PC
# 3        NaN        NaN          NaN  SOUTHEASTERN INTENSIVIST SERVICES PC
# 4        NaN        NaN          NaN  SOUTHEASTERN INTENSIVIST SERVICES PC
#
#      org_pac_id  num_org_mem                  adr_ln_1 adr_ln_2 ln_2_sprs  \
# 0  8.022915e+09        182.0        1850 TOWN CTR PKWY      NaN       NaN
# 1  8.022915e+09        182.0    1701 N GEORGE MASON DR      NaN       NaN
# 2  8.022915e+09        182.0  24440 STONE SPRINGS BLVD      NaN       NaN
# 3  9.335152e+09        133.0   1401 JOHNSTON WILLIS DR      NaN       NaN
# 4  9.335152e+09        133.0         411 W RANDOLPH RD      NaN       NaN
#
#                   cty  st        zip     phn_numbr hosp_afl_1  \
# 0              RESTON  VA  201903219  7.036899e+09     490112
# 1           ARLINGTON  VA  222053610  7.035586e+09     490112
# 2              DULLES  VA  201662247  5.713674e+09     490112
# 3  NORTH CHESTERFIELD  VA  232354730  8.044835e+09     490112
# 4            HOPEWELL  VA  238602938  8.045412e+09     490112
#
#        hosp_afl_lbn_1 hosp_afl_2                 hosp_afl_lbn_2 hosp_afl_3  \
# 0  CJW MEDICAL CENTER     210028  MEDSTAR SAINT MARY'S HOSPITAL        NaN
# 1  CJW MEDICAL CENTER     210028  MEDSTAR SAINT MARY'S HOSPITAL        NaN
# 2  CJW MEDICAL CENTER     210028  MEDSTAR SAINT MARY'S HOSPITAL        NaN
# 3  CJW MEDICAL CENTER     210028  MEDSTAR SAINT MARY'S HOSPITAL        NaN
# 4  CJW MEDICAL CENTER     210028  MEDSTAR SAINT MARY'S HOSPITAL        NaN
#
#   hosp_afl_lbn_3 hosp_afl_4 hosp_afl_lbn_4  hosp_afl_5 hosp_afl_lbn_5 assgn
# 0            NaN        NaN            NaN         NaN            NaN     Y
# 1            NaN        NaN            NaN         NaN            NaN     Y
# 2            NaN        NaN            NaN         NaN            NaN     Y
# 3            NaN        NaN            NaN         NaN            NaN     Y
# 4            NaN        NaN            NaN         NaN            NaN     Y

# %%
# get overview of the columns and dtypes within each one
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2210790 entries, 0 to 2210789
# Data columns (total 38 columns):
# npi               int64
# ind_pac_id        int64
# ind_enrl_id       object
# lst_nm            object
# frst_nm           object
# mid_nm            object
# suff              object
# gndr              object
# cred              object
# med_sch           object
# grd_yr            float64
# pri_spec          object
# sec_spec_1        object
# sec_spec_2        object
# sec_spec_3        object
# sec_spec_4        object
# sec_spec_all      object
# org_lgl_nm        object
# org_pac_id        float64
# num_org_mem       float64
# adr_ln_1          object
# adr_ln_2          object
# ln_2_sprs         object
# cty               object
# st                object
# zip               object
# phn_numbr         float64
# hosp_afl_1        object
# hosp_afl_lbn_1    object
# hosp_afl_2        object
# hosp_afl_lbn_2    object
# hosp_afl_3        object
# hosp_afl_lbn_3    object
# hosp_afl_4        object
# hosp_afl_lbn_4    object
# hosp_afl_5        float64
# hosp_afl_lbn_5    object
# assgn             object
# dtypes: float64(5), int64(2), object(31)
# memory usage: 640.9+ MB

# %%
# see the percentage of observations that are NaNs in each column
round((data.isna().mean() * 100), 3)
# Out:
# npi                0.000
# ind_pac_id         0.000
# ind_enrl_id        0.000
# lst_nm             0.002
# frst_nm            0.001
# mid_nm            24.582
# suff              98.164
# gndr               0.000
# cred              68.976
# med_sch            0.000
# grd_yr             0.235
# pri_spec           0.000
# sec_spec_1        85.576
# sec_spec_2        98.406
# sec_spec_3        99.833
# sec_spec_4        99.973
# sec_spec_all      85.576
# org_lgl_nm         8.051
# org_pac_id         8.051
# num_org_mem        8.051
# adr_ln_1           0.000
# adr_ln_2          65.159
# ln_2_sprs         94.270
# cty                0.000
# st                 0.000
# zip                0.000
# phn_numbr         15.288
# hosp_afl_1        26.610
# hosp_afl_lbn_1    26.715
# hosp_afl_2        59.499
# hosp_afl_lbn_2    59.635
# hosp_afl_3        76.644
# hosp_afl_lbn_3    76.739
# hosp_afl_4        85.746
# hosp_afl_lbn_4    85.799
# hosp_afl_5        90.769
# hosp_afl_lbn_5    90.807
# assgn              0.000
# dtype: float64

# %% [markdown]
# Ok so we can see that there are quite a few columns that have a significant number of `NaN`s, which is something we'll have to address as we move forward. However, `ind_enrl_id` looks good to go, which is a good first step. The next thing we'll take a look out after exploring `ind_enrl_id` is how to possibly combine the first, middle and last name into one column, or if it is even necessary.

# %%
# see how many unique professional enrollment ID numbers there are
len(data['ind_enrl_id'].unique())
# Out:
# 1147121

# %% [markdown]
# Ok so there appears to be a little over 1.1 million unique professional enrollment IDs in the data set, which is way less than the total number of observations.

# %%
# combine first and last name
data['frst_nm'].str.cat(data['lst_nm'], sep=" ")
# Out:
# 0            ARDALAN ENKESHAFI
# 1            ARDALAN ENKESHAFI
# 2            ARDALAN ENKESHAFI
# 3            ARDALAN ENKESHAFI
# 4            ARDALAN ENKESHAFI
# 5                THOMAS CIBULL
# 6                THOMAS CIBULL
# 7                THOMAS CIBULL
# 8                THOMAS CIBULL
# 9                THOMAS CIBULL
# 10               THOMAS CIBULL
# 11               THOMAS CIBULL
# 12               THOMAS CIBULL
# 13               THOMAS CIBULL
# 14               RASHID KHALIL
# 15               RASHID KHALIL
# 16               RASHID KHALIL
# 17               RASHID KHALIL
# 18               RASHID KHALIL
# 19               RASHID KHALIL
# 20            JENNIFER VELOTTA
# 21             KEVIN ROTHCHILD
# 22             KEVIN ROTHCHILD
# 23           FREDERICK WEIGAND
# 24           FREDERICK WEIGAND
# 25           FREDERICK WEIGAND
# 26             AMANDA SEMONCHE
# 27             AMANDA SEMONCHE
# 28                     DAE KIM
# 29            PEYMAN BENHARASH
#                   ...
# 2210760             LISA DRIES
# 2210761             LISA DRIES
# 2210762     SESHASREE MARUPUDI
# 2210763          SUSAN GIBBONS
# 2210764           ADAM LANGLEY
# 2210765            JAMES HODGE
# 2210766            ALBERT PARK
# 2210767            ALBERT PARK
# 2210768            ALBERT PARK
# 2210769            ALBERT PARK
# 2210770       SVETLANA TSIRKIN
# 2210771             RAHUL NAIK
# 2210772        KATHRYN CARROLL
# 2210773        CHARLES JOHNSON
# 2210774        CHARLES JOHNSON
# 2210775    CHRISTOPHER SERPICO
# 2210776      STEPHANIE BENNETT
# 2210777      STEPHANIE BENNETT
# 2210778      STEPHANIE BENNETT
# 2210779           JOHN HEILMAN
# 2210780           INDIRA MOLAI
# 2210781             JENNY YUEN
# 2210782           DINO SORIANO
# 2210783         GREG TAKENISHI
# 2210784     GEOFFREY DESCHENES
# 2210785     GEOFFREY DESCHENES
# 2210786     GEOFFREY DESCHENES
# 2210787     GEOFFREY DESCHENES
# 2210788     GEOFFREY DESCHENES
# 2210789     GEOFFREY DESCHENES
# Name: frst_nm, Length: 2210790, dtype: object

# %% [markdown]
# As we can see above, there are multiple cases duplicate entries are evident by combining first and last name. Now let's see how many unique names there are.

# %%
# combine first and last name and see how many unique names there are
len(data['frst_nm'].str.cat(data['lst_nm'], sep=" ").unique())
# Out:
# 933045

# %% [markdown]
# Interesting...there are `933045` unique names but `1147121` unique professional enrollment IDs. That's a difference of over 200k+ observations! What is going on here?

# %%
# let's revisit how many missing values there are in the name-related columns
data[['lst_nm', 'frst_nm', 'mid_nm', 'suff']].isna().sum()
# Out:
# lst_nm          37
# frst_nm         24
# mid_nm      543463
# suff       2170208
# dtype: int64

# %%
# let's replace the NaNs with blank "" to make them a little easier to work with
data[['lst_nm', 'frst_nm']] = data[['lst_nm', 'frst_nm']].fillna(value="")

# %%
# let's dive into the missing values for first and last name
data[data['lst_nm'] == ""]
# Out:
#                 npi  ind_pac_id      ind_enrl_id lst_nm    frst_nm     mid_nm  \
# 136176   1063454130  8628071131  I20060822000324          BENJAMIN     HANBOK
# 136177   1063454130  8628071131  I20060822000324          BENJAMIN     HANBOK
# 177939   1083084875  4284937251  I20160125002851            TRAVIS          J
# 243886   1114025665   941246326  I20050707000585             TERRY        NaN
# 243887   1114025665   941246326  I20050707000585             TERRY        NaN
# 298158   1134289879   941201511  I20070124000749             STEVE          C
# 298159   1134289879   941201511  I20070124000749             STEVE          C
# 352205   1154847614  3375802556  I20180116000499             TANYA          M
# 445731   1205119435   840458907  I20120221000078         CHRISTINE          M
# 445732   1205119435   840458907  I20120221000078         CHRISTINE          M
# 466178   1215064852  2860663416  I20140417002113         ELIZABETH        ANN
# 466179   1215064852  2860663416  I20140417002113         ELIZABETH        ANN
# 466180   1215064852  2860663416  I20140417002113         ELIZABETH        ANN
# 466181   1215064852  2860663416  I20140417002113         ELIZABETH        ANN
# 466182   1215064852  2860663416  I20140417002113         ELIZABETH        ANN
# 466183   1215064852  2860663416  I20140417002113         ELIZABETH        ANN
# 506570   1225488034  2860780723  I20161007001210             SARAH          M
# 555152   1255328902  4880614916  I20111207000177              SANG        NaN
# 621584   1285078295  9133492952  I20170830001109              HANA        NaN
# 621585   1285078295  9133492952  I20170901003155              HANA        NaN
# 686317   1316017429  6103013941  I20101207000117            WALTER          B
# 733084   1336129444  2365505997  I20090108000380           DANETTE        NaN
# 1057235  1477816874  7618264391  I20160923000168             MANDA        NaN
# 1284693  1588000723  3274830526  I20160331000662           COLLEEN          E
# 1332889  1609131598   941520084  I20190422000630            KENDRA          R
# 1511204  1689638744   941384515  I20080221000334            DANIEL          H
# 1511205  1689638744   941384515  I20080221000334            DANIEL          H
# 1515978  1689695553  4385691112  I20050405000171             SCOTT          A
# 1550051  1700049269  4284872789  I20130522000411                XI        NaN
# 1657935  1740768993  3173872769  I20180815000176             LOGAN       ALAN
# 1714641  1770676231  1456545813  I20180129002718            ANGELA          D
# 1877653  1841655669  1456655059  I20160202000675            PAMELA          A
# 1889107  1851440127  8022284272  I20120112000520              SONG          H
# 1895936  1851614648  5698952638  I20110531000663              GINA          D
# 2076047  1932547866  4981847456  I20190531001894            ROBERT  CHRISTIAN
# 2076048  1932547866  4981847456  I20190603001511            ROBERT  CHRISTIAN
# 2111350  1952483950  4587826714  I20120503000468            ROBERT          N
#
#         suff gndr cred                                            med_sch  \
# 136176   NaN    M   OD                                              OTHER
# 136177   NaN    M   OD                                              OTHER
# 177939   NaN    M  NaN                                              OTHER
# 243886   NaN    M   OD           INDIANA UNIVERSITY - SCHOOL OF OPTOMETRY
# 243887   NaN    M   OD           INDIANA UNIVERSITY - SCHOOL OF OPTOMETRY
# 298158   NaN    M   MD                                              OTHER
# 298159   NaN    M   MD                                              OTHER
# 352205   NaN    F  NaN                                              OTHER
# 445731   NaN    F  NaN                                              OTHER
# 445732   NaN    F  NaN                                              OTHER
# 466178   NaN    F  NaN                                              OTHER
# 466179   NaN    F  NaN                                              OTHER
# 466180   NaN    F  NaN                                              OTHER
# 466181   NaN    F  NaN                                              OTHER
# 466182   NaN    F  NaN                                              OTHER
# 466183   NaN    F  NaN                                              OTHER
# 506570   NaN    F  NaN                                              OTHER
# 555152   NaN    M   MD          UNIVERSITY OF MARYLAND SCHOOL OF MEDICINE
# 621584   NaN    F  NaN                  GEORGETOWN UNIVERSITY OF MEDICINE
# 621585   NaN    F  NaN                  GEORGETOWN UNIVERSITY OF MEDICINE
# 686317    IV    M  NaN                      NEW YORK CHIROPRACTIC COLLEGE
# 733084   NaN    F  NaN  LOUISIANA STATE UNIVERSITY SCHOOL OF MEDICINE ...
# 1057235  NaN    F  NaN  ARIZONA COLLEGE OF OSTEOPATHIC MEDICINE MID WE...
# 1284693  NaN    F  NaN                                              OTHER
# 1332889  NaN    F  NaN                      SOUTHERN COLLEGE OF OPTOMETRY
# 1511204  NaN    M  NaN  UNIVERSITY OF CALIFORNIA, SAN FRANCISCO SCHOOL...
# 1511205  NaN    M  NaN  UNIVERSITY OF CALIFORNIA, SAN FRANCISCO SCHOOL...
# 1515978  NaN    M   DC            PALMER COLLEGE CHIROPRACTIC - DAVENPORT
# 1550051  NaN    F  NaN                                              OTHER
# 1657935  NaN    M  NaN                          LIFE CHIROPRACTIC COLLEGE
# 1714641  NaN    F  NaN                                              OTHER
# 1877653  NaN    F  NaN                                              OTHER
# 1889107  NaN    M  NaN                EMORY UNIVERSITY SCHOOL OF MEDICINE
# 1895936  NaN    F  NaN                                              OTHER
# 2076047  NaN    M  NaN             UNIVERSITY OF IOWA COLLEGE OF MEDICINE
# 2076048  NaN    M  NaN             UNIVERSITY OF IOWA COLLEGE OF MEDICINE
# 2111350  NaN    M  NaN                                              OTHER
#
#          grd_yr                             pri_spec         sec_spec_1  \
# 136176   2001.0                            OPTOMETRY                NaN
# 136177   2001.0                            OPTOMETRY                NaN
# 177939   2015.0                   NURSE PRACTITIONER                NaN
# 243886   1983.0                            OPTOMETRY                NaN
# 243887   1983.0                            OPTOMETRY                NaN
# 298158   2003.0                      FAMILY MEDICINE                NaN
# 298159   2003.0                      FAMILY MEDICINE                NaN
# 352205   2017.0                   NURSE PRACTITIONER                NaN
# 445731   2011.0                     PHYSICAL THERAPY                NaN
# 445732   2011.0                     PHYSICAL THERAPY                NaN
# 466178      NaN                            NEUROLOGY                NaN
# 466179      NaN                            NEUROLOGY                NaN
# 466180      NaN                            NEUROLOGY                NaN
# 466181      NaN                            NEUROLOGY                NaN
# 466182      NaN                            NEUROLOGY                NaN
# 466183      NaN                            NEUROLOGY                NaN
# 506570   2016.0                   NURSE PRACTITIONER                NaN
# 555152   1992.0  CARDIOVASCULAR DISEASE (CARDIOLOGY)   THORACIC SURGERY
# 621584   2013.0                        OPHTHALMOLOGY                NaN
# 621585   2013.0                        OPHTHALMOLOGY                NaN
# 686317   2000.0                         CHIROPRACTIC                NaN
# 733084   2001.0                      FAMILY MEDICINE                NaN
# 1057235  2012.0                       ANESTHESIOLOGY                NaN
# 1284693  2012.0               CLINICAL SOCIAL WORKER                NaN
# 1332889  2012.0                            OPTOMETRY                NaN
# 1511204  1990.0                    INTERNAL MEDICINE                NaN
# 1511205  1990.0                    INTERNAL MEDICINE                NaN
# 1515978  1980.0                         CHIROPRACTIC                NaN
# 1550051  1997.0                     GASTROENTEROLOGY  INTERNAL MEDICINE
# 1657935  2017.0                         CHIROPRACTIC                NaN
# 1714641  1993.0               PSYCHOLOGIST, CLINICAL                NaN
# 1877653  2015.0                   NURSE PRACTITIONER                NaN
# 1889107  1991.0                    INTERNAL MEDICINE                NaN
# 1895936  2009.0                   NURSE PRACTITIONER                NaN
# 2076047  2013.0                        OPHTHALMOLOGY                NaN
# 2076048  2013.0                        OPHTHALMOLOGY                NaN
# 2111350  1981.0                  PHYSICIAN ASSISTANT                NaN
#
#                sec_spec_2 sec_spec_3 sec_spec_4  \
# 136176                NaN        NaN        NaN
# 136177                NaN        NaN        NaN
# 177939                NaN        NaN        NaN
# 243886                NaN        NaN        NaN
# 243887                NaN        NaN        NaN
# 298158                NaN        NaN        NaN
# 298159                NaN        NaN        NaN
# 352205                NaN        NaN        NaN
# 445731                NaN        NaN        NaN
# 445732                NaN        NaN        NaN
# 466178                NaN        NaN        NaN
# 466179                NaN        NaN        NaN
# 466180                NaN        NaN        NaN
# 466181                NaN        NaN        NaN
# 466182                NaN        NaN        NaN
# 466183                NaN        NaN        NaN
# 506570                NaN        NaN        NaN
# 555152   VASCULAR SURGERY        NaN        NaN
# 621584                NaN        NaN        NaN
# 621585                NaN        NaN        NaN
# 686317                NaN        NaN        NaN
# 733084                NaN        NaN        NaN
# 1057235               NaN        NaN        NaN
# 1284693               NaN        NaN        NaN
# 1332889               NaN        NaN        NaN
# 1511204               NaN        NaN        NaN
# 1511205               NaN        NaN        NaN
# 1515978               NaN        NaN        NaN
# 1550051               NaN        NaN        NaN
# 1657935               NaN        NaN        NaN
# 1714641               NaN        NaN        NaN
# 1877653               NaN        NaN        NaN
# 1889107               NaN        NaN        NaN
# 1895936               NaN        NaN        NaN
# 2076047               NaN        NaN        NaN
# 2076048               NaN        NaN        NaN
# 2111350               NaN        NaN        NaN
#
#                                sec_spec_all  \
# 136176                                  NaN
# 136177                                  NaN
# 177939                                  NaN
# 243886                                  NaN
# 243887                                  NaN
# 298158                                  NaN
# 298159                                  NaN
# 352205                                  NaN
# 445731                                  NaN
# 445732                                  NaN
# 466178                                  NaN
# 466179                                  NaN
# 466180                                  NaN
# 466181                                  NaN
# 466182                                  NaN
# 466183                                  NaN
# 506570                                  NaN
# 555152   THORACIC SURGERY, VASCULAR SURGERY
# 621584                                  NaN
# 621585                                  NaN
# 686317                                  NaN
# 733084                                  NaN
# 1057235                                 NaN
# 1284693                                 NaN
# 1332889                                 NaN
# 1511204                                 NaN
# 1511205                                 NaN
# 1515978                                 NaN
# 1550051                   INTERNAL MEDICINE
# 1657935                                 NaN
# 1714641                                 NaN
# 1877653                                 NaN
# 1889107                                 NaN
# 1895936                                 NaN
# 2076047                                 NaN
# 2076048                                 NaN
# 2111350                                 NaN
#
#                                                 org_lgl_nm    org_pac_id  \
# 136176                                                 NaN           NaN
# 136177                                                 NaN           NaN
# 177939            NORTHWEST MEDICAL CENTER ASSOCIATION INC  5.496642e+09
# 243886                              VISIONQUEST EYECARE PC  7.517951e+09
# 243887                              VISIONQUEST EYECARE PC  7.517951e+09
# 298158        SOUTHERN CALIFORNIA PERMANENTE MEDICAL GROUP  6.002729e+09
# 298159        SOUTHERN CALIFORNIA PERMANENTE MEDICAL GROUP  6.002729e+09
# 352205                       FAYETTE PHYSICIAN NETWORK INC  3.375866e+09
# 445731                    SUTTER VALLEY MEDICAL FOUNDATION  9.830095e+09
# 445732                    SUTTER VALLEY MEDICAL FOUNDATION  9.830095e+09
# 466178                    MAURY REGIONAL MEDICAL GROUP INC  7.911811e+09
# 466179                    MAURY REGIONAL MEDICAL GROUP INC  7.911811e+09
# 466180                    MAURY REGIONAL MEDICAL GROUP INC  7.911811e+09
# 466181                    MAURY REGIONAL MEDICAL GROUP INC  7.911811e+09
# 466182                    MAURY REGIONAL MEDICAL GROUP INC  7.911811e+09
# 466183                    MAURY REGIONAL MEDICAL GROUP INC  7.911811e+09
# 506570                       MARY IMOGENE BASSETT HOSPITAL  3.779488e+09
# 555152               MARY WASHINGTON HEALTHCARE PHYSICIANS  2.769547e+09
# 621584                               DULLES EYE ASSOCIATES  9.638067e+09
# 621585                               DULLES EYE ASSOCIATES  9.638067e+09
# 686317                      POWELL CHIROPRACTIC CLINIC INC  2.769416e+09
# 733084                LSUHSC FAMILY PRACTICE CENTER @ LCMH  4.229756e+07
# 1057235              COMMUNITY ANESTHESIA ASSOCIATES, LTD.  4.462362e+08
# 1284693                UNIVERSITY OF TOLEDO PHYSICIANS LLC  8.729983e+09
# 1332889                                        EYE CARE PA  4.385545e+09
# 1511204               UCSF MEDICAL GROUP BUSINESS SERVICES  3.779498e+09
# 1511205  UNIVERSITY OF CALIFORNIA SAN FRANCISCO MEDICAL...  4.486567e+09
# 1515978                              NULL CHIROPRACTIC LLC  5.890947e+09
# 1550051                   DIGESTIVE HEALTH ASSOCIATES P.C.  8.527017e+09
# 1657935                              NULL CHIROPRACTIC LLC  5.890947e+09
# 1714641                                        PSYCARE INC  1.759311e+09
# 1877653                     DUBOIS REGIONAL MEDICAL CENTER  5.890690e+09
# 1889107                                                NaN           NaN
# 1895936               UROLOGIC SPECIALISTS OF OKLAHOMA INC  3.779470e+09
# 2076047                                        EYE CARE PA  4.385545e+09
# 2076048                                        EYE CARE PA  4.385545e+09
# 2111350                HAWAII PERMANENTE MEDICAL GROUP INC  7.618881e+09
#
#          num_org_mem                   adr_ln_1  \
# 136176           NaN             115 W 25TH AVE
# 136177           NaN        3191 CROW CANYON PL
# 177939           5.0          1607 E US HWY 136
# 243886           6.0        1160 N STATE RD 135
# 243887           6.0       9650 E WASHINGTON ST
# 298158        8118.0    30400 CAMINO CAPISTRANO
# 298159        8118.0        5475 E LA PALMA AVE
# 352205          99.0                 25 MAIN ST
# 445731        1492.0       9280 W STOCKTON BLVD
# 445732        1492.0                  2800 L ST
# 466178         144.0  854 W JAMES CAMPBELL BLVD
# 466179         144.0          1224 TROTWOOD AVE
# 466180         144.0          1222 TROTWOOD AVE
# 466181         144.0         101 JV MANGUBAT DR
# 466182         144.0         103 JV MANGUBAT DR
# 466183         144.0         103 JV MANGUBAT DR
# 506570         559.0             140 BURWELL ST
# 555152         159.0        1101 SAM PERRY BLVD
# 621584           5.0        19415 DEERFIELD AVE
# 621585           5.0        8316 ARLINGTON BLVD
# 686317           3.0          4867 MUNSON ST NW
# 733084           9.0         1525 OAK PARK BLVD
# 1057235          5.0          1500 HIGHLANDS DR
# 1284693        313.0         3125 TRANSVERSE DR
# 1332889         43.0          4741 S COCHISE DR
# 1511204        592.0          400 PARNASSUS AVE
# 1511205       1192.0          400 PARNASSUS AVE
# 1515978          3.0             204 E CHESTNUT
# 1550051          9.0            91 MONTVALE AVE
# 1657935          3.0             204 E CHESTNUT
# 1714641          8.0                312 6TH AVE
# 1877653        263.0              621 S MAIN ST
# 1889107          NaN    4995 LANIER ISLAND PKWY
# 1895936         31.0             2713 S 74TH ST
# 2076047         43.0           11500 GRANADA ST
# 2076048         43.0          4741 S COCHISE DR
# 2111350        540.0           3288 MOANALUA RD
#
#                                adr_ln_2 ln_2_sprs                  cty  st  \
# 136176                              NaN       NaN            SAN MATEO  CA
# 136177                          SUITE C       NaN            SAN RAMON  CA
# 177939   MOSAIC FAMILY CARE ALBANY EAST       NaN               ALBANY  MO
# 243886                              NaN       NaN            GREENWOOD  IN
# 243887                              NaN       NaN         INDIANAPOLIS  IN
# 298158                              NaN       NaN  SAN JUAN CAPISTRANO  CA
# 298159                              NaN       NaN              ANAHEIM  CA
# 352205                              NaN       NaN           SMITHFIELD  PA
# 445731                        SUITE 116       NaN            ELK GROVE  CA
# 445732                              NaN         Y           SACRAMENTO  CA
# 466178                              NaN         Y             COLUMBIA  TN
# 466179                              NaN       NaN             COLUMBIA  TN
# 466180                              NaN         Y             COLUMBIA  TN
# 466181                          SUITE B       NaN           WAYNESBORO  TN
# 466182                              NaN       NaN           WAYNESBORO  TN
# 466183                             FL 3       NaN           WAYNESBORO  TN
# 506570                              NaN       NaN         LITTLE FALLS  NY
# 555152                        SUITE 211       NaN       FREDERICKSBURG  VA
# 621584                        SUITE 106       NaN            LANSDOWNE  VA
# 621585                        SUITE 640       NaN              FAIRFAX  VA
# 686317                              NaN       NaN               CANTON  OH
# 733084                              NaN       NaN         LAKE CHARLES  LA
# 1057235                             NaN       NaN               LITITZ  PA
# 1284693                             NaN       NaN               TOLEDO  OH
# 1332889                             NaN       NaN         INDEPENDENCE  MO
# 1511204                             NaN       NaN        SAN FRANCISCO  CA
# 1511205                          MCB300       NaN        SAN FRANCISCO  CA
# 1515978                             NaN       NaN         INDEPENDENCE  KS
# 1550051                       SUITE 206       NaN             STONEHAM  MA
# 1657935                             NaN       NaN         INDEPENDENCE  KS
# 1714641                         SUITE 2       NaN     SOUTH CHARLESTON  WV
# 1877653    PENN HIGHLANDS Q CARE DUBOIS       NaN               DUBOIS  PA
# 1889107                         SUITE A       NaN               BUFORD  GA
# 1895936                       SUITE 104       NaN           FORT SMITH  AR
# 2076047                             NaN       NaN              LEAWOOD  KS
# 2076048                             NaN       NaN         INDEPENDENCE  MO
# 2111350                             NaN       NaN             HONOLULU  HI
#
#                zip     phn_numbr hosp_afl_1  \
# 136176   944032259  6.503496e+09        NaN
# 136177   945831349  9.252441e+09        NaN
# 177939   644028223  6.607263e+09     261328
# 243886   461421019  3.178657e+09        NaN
# 243887   462293032  3.178906e+09        NaN
# 298158   926751300  9.492342e+09        NaN
# 298159   928072075  7.142796e+09        NaN
# 352205   154788943  7.245691e+09        NaN
# 445731   957588073  9.166833e+09        NaN
# 445732   958165616           NaN        NaN
# 466178   384014672           NaN     440073
# 466179   384014802  9.313811e+09     440073
# 466180   384016404           NaN     440073
# 466181   384852440  9.317230e+09     440073
# 466182   384852440  9.317225e+09     440073
# 466183   384852440  9.317222e+09     440073
# 506570   133651725  3.158231e+09     331311
# 555152   224014465  5.403728e+09     490022
# 621584   201768470  7.037240e+09        NaN
# 621585   220315216  7.037240e+09        NaN
# 686317   447183614  3.304946e+09        NaN
# 733084   706018849  3.374947e+09     190060
# 1057235  175437694  7.176256e+09     390068
# 1284693  436148008  4.193835e+09     360048
# 1332889  640556974  8.164781e+09        NaN
# 1511204  941432202  4.154761e+09      50454
# 1511205  941430810  4.154761e+09      50454
# 1515978  673013132  6.203312e+09        NaN
# 1550051  021803649  7.814386e+09     220105
# 1657935  673013132  6.203312e+09        NaN
# 1714641  253031265  3.047686e+12        NaN
# 1877653  158011413  8.142998e+09     390086
# 1889107  305181741           NaN     110087
# 1895936  729035174  9.187499e+09        NaN
# 2076047  662111453  8.164781e+09     160079
# 2076048  640556974  8.164781e+09     160079
# 2111350  968191469  8.084320e+09        NaN
#
#                                      hosp_afl_lbn_1 hosp_afl_2  \
# 136176                                          NaN        NaN
# 136177                                          NaN        NaN
# 177939                     NORTHWEST MEDICAL CENTER     260006
# 243886                                          NaN        NaN
# 243887                                          NaN        NaN
# 298158                                          NaN        NaN
# 298159                                          NaN        NaN
# 352205                                          NaN        NaN
# 445731                                          NaN        NaN
# 445732                                          NaN        NaN
# 466178                      MAURY REGIONAL HOSPITAL     441309
# 466179                      MAURY REGIONAL HOSPITAL     441309
# 466180                      MAURY REGIONAL HOSPITAL     441309
# 466181                      MAURY REGIONAL HOSPITAL     441309
# 466182                      MAURY REGIONAL HOSPITAL     441309
# 466183                      MAURY REGIONAL HOSPITAL     441309
# 506570                        LITTLE FALLS HOSPITAL     330136
# 555152                     MARY WASHINGTON HOSPITAL        NaN
# 621584                                          NaN        NaN
# 621585                                          NaN        NaN
# 686317                                          NaN        NaN
# 733084               LAKE CHARLES MEMORIAL HOSPITAL     190027
# 1057235  HEART OF LANCASTER REGIONAL MEDICAL CENTER        NaN
# 1284693         UNIVERSITY OF TOLEDO MEDICAL CENTER        NaN
# 1332889                                         NaN        NaN
# 1511204                         UCSF MEDICAL CENTER      50457
# 1511205                         UCSF MEDICAL CENTER      50457
# 1515978                                         NaN        NaN
# 1550051                         WINCHESTER HOSPITAL        NaN
# 1657935                                         NaN        NaN
# 1714641                                         NaN        NaN
# 1877653                        PENN HIGHLAND DUBOIS        NaN
# 1889107                     GWINNETT MEDICAL CENTER     110029
# 1895936                                         NaN        NaN
# 2076047         MERCY MEDICAL CENTER - CEDAR RAPIDS     161344
# 2076048         MERCY MEDICAL CENTER - CEDAR RAPIDS     161344
# 2111350                                         NaN        NaN
#
#                                  hosp_afl_lbn_2 hosp_afl_3  \
# 136176                                      NaN        NaN
# 136177                                      NaN        NaN
# 177939            MOSAIC LIFE CARE AT ST JOSEPH        NaN
# 243886                                      NaN        NaN
# 243887                                      NaN        NaN
# 298158                                      NaN        NaN
# 298159                                      NaN        NaN
# 352205                                      NaN        NaN
# 445731                                      NaN        NaN
# 445732                                      NaN        NaN
# 466178                  MARSHALL MEDICAL CENTER     440010
# 466179                  MARSHALL MEDICAL CENTER     440010
# 466180                  MARSHALL MEDICAL CENTER     440010
# 466181                  MARSHALL MEDICAL CENTER     440010
# 466182                  MARSHALL MEDICAL CENTER     440010
# 466183                  MARSHALL MEDICAL CENTER     440010
# 506570                       BASSETT HEALTHCARE        NaN
# 555152                                      NaN        NaN
# 621584                                      NaN        NaN
# 621585                                      NaN        NaN
# 686317                                      NaN        NaN
# 733084             CHRISTUS ST PATRICK HOSPITAL        NaN
# 1057235                                     NaN        NaN
# 1284693                                     NaN        NaN
# 1332889                                     NaN        NaN
# 1511204                ST MARY'S MEDICAL CENTER        NaN
# 1511205                ST MARY'S MEDICAL CENTER        NaN
# 1515978                                     NaN        NaN
# 1550051                                     NaN        NaN
# 1657935                                     NaN        NaN
# 1714641                                     NaN        NaN
# 1877653                                     NaN        NaN
# 1889107   NORTHEAST GEORGIA MEDICAL CENTER, INC     110161
# 1895936                                     NaN        NaN
# 2076047  WASHINGTON COUNTY HOSPITAL AND CLINICS     160001
# 2076048  WASHINGTON COUNTY HOSPITAL AND CLINICS     160001
# 2111350                                     NaN        NaN
#
#                          hosp_afl_lbn_3 hosp_afl_4        hosp_afl_lbn_4  \
# 136176                              NaN        NaN                   NaN
# 136177                              NaN        NaN                   NaN
# 177939                              NaN        NaN                   NaN
# 243886                              NaN        NaN                   NaN
# 243887                              NaN        NaN                   NaN
# 298158                              NaN        NaN                   NaN
# 298159                              NaN        NaN                   NaN
# 352205                              NaN        NaN                   NaN
# 445731                              NaN        NaN                   NaN
# 445732                              NaN        NaN                   NaN
# 466178             WAYNE MEDICAL CENTER        NaN                   NaN
# 466179             WAYNE MEDICAL CENTER        NaN                   NaN
# 466180             WAYNE MEDICAL CENTER        NaN                   NaN
# 466181             WAYNE MEDICAL CENTER        NaN                   NaN
# 466182             WAYNE MEDICAL CENTER        NaN                   NaN
# 466183             WAYNE MEDICAL CENTER        NaN                   NaN
# 506570                              NaN        NaN                   NaN
# 555152                              NaN        NaN                   NaN
# 621584                              NaN        NaN                   NaN
# 621585                              NaN        NaN                   NaN
# 686317                              NaN        NaN                   NaN
# 733084                              NaN        NaN                   NaN
# 1057235                             NaN        NaN                   NaN
# 1284693                             NaN        NaN                   NaN
# 1332889                             NaN        NaN                   NaN
# 1511204                             NaN        NaN                   NaN
# 1511205                             NaN        NaN                   NaN
# 1515978                             NaN        NaN                   NaN
# 1550051                             NaN        NaN                   NaN
# 1657935                             NaN        NaN                   NaN
# 1714641                             NaN        NaN                   NaN
# 1877653                             NaN        NaN                   NaN
# 1889107              NORTHSIDE HOSPITAL        NaN                   NaN
# 1895936                             NaN        NaN                   NaN
# 2076047  UNITYPOINT HEALTH-MARSHALLTOWN     160032  SKIFF MEDICAL CENTER
# 2076048  UNITYPOINT HEALTH-MARSHALLTOWN     160032  SKIFF MEDICAL CENTER
# 2111350                             NaN        NaN                   NaN
#
#          hosp_afl_5 hosp_afl_lbn_5 assgn
# 136176          NaN            NaN     Y
# 136177          NaN            NaN     Y
# 177939          NaN            NaN     Y
# 243886          NaN            NaN     Y
# 243887          NaN            NaN     Y
# 298158          NaN            NaN     Y
# 298159          NaN            NaN     Y
# 352205          NaN            NaN     Y
# 445731          NaN            NaN     Y
# 445732          NaN            NaN     Y
# 466178          NaN            NaN     Y
# 466179          NaN            NaN     Y
# 466180          NaN            NaN     Y
# 466181          NaN            NaN     Y
# 466182          NaN            NaN     Y
# 466183          NaN            NaN     Y
# 506570          NaN            NaN     Y
# 555152          NaN            NaN     Y
# 621584          NaN            NaN     Y
# 621585          NaN            NaN     Y
# 686317          NaN            NaN     Y
# 733084          NaN            NaN     Y
# 1057235         NaN            NaN     Y
# 1284693         NaN            NaN     Y
# 1332889         NaN            NaN     Y
# 1511204         NaN            NaN     Y
# 1511205         NaN            NaN     Y
# 1515978         NaN            NaN     Y
# 1550051         NaN            NaN     Y
# 1657935         NaN            NaN     Y
# 1714641         NaN            NaN     Y
# 1877653         NaN            NaN     Y
# 1889107         NaN            NaN     Y
# 1895936         NaN            NaN     Y
# 2076047         NaN            NaN     Y
# 2076048         NaN            NaN     Y
# 2111350         NaN            NaN     Y

# %%
data[data['frst_nm'] == ""]
# Out:
#                 npi  ind_pac_id      ind_enrl_id lst_nm frst_nm mid_nm suff  \
# 80900    1033381983  4183808488  I20110412000132     MA            NaN  NaN
# 80901    1033381983  4183808488  I20110412000132     MA            NaN  NaN
# 80902    1033381983  4183808488  I20110412000132     MA            NaN  NaN
# 128852   1053726695    42532210  I20190130002955    JEN            NaN  NaN
# 500235   1225268824  4385868678  I20140605002253   SHEN            NaN  NaN
# 500236   1225268824  4385868678  I20140605002253   SHEN            NaN  NaN
# 500237   1225268824  4385868678  I20140605002253   SHEN            NaN  NaN
# 885207   1407012263  8527215920  I20120820000693    LEE              Y  NaN
# 1138928  1518288307  4082929229  I20150817001415    LIU            NaN  NaN
# 1141501  1518399344  6002138021  I20141202002187   VANG            NaN  NaN
# 1141502  1518399344  6002138021  I20141202002187   VANG            NaN  NaN
# 1304346  1588922041  7113148420  I20151019002117     LI            NaN  NaN
# 1428411  1649416504  4385883222  I20130625000455     LI            NaN  NaN
# 1428412  1649416504  4385883222  I20130625000455     LI            NaN  NaN
# 1428413  1649416504  4385883222  I20130625000455     LI            NaN  NaN
# 1428414  1649416504  4385883222  I20130625000455     LI            NaN  NaN
# 1428415  1649416504  4385883222  I20130625000455     LI            NaN  NaN
# 1428416  1649416504  4385883222  I20130625000455     LI            NaN  NaN
# 1693799  1760644967  1951681220  I20161201001930   YANG            NaN  NaN
# 1744769  1780918615  8426196981  I20091104000162     LI            NaN  NaN
# 1744770  1780918615  8426196981  I20091104000162     LI            NaN  NaN
# 1802680  1811350218  8325332901  I20170816002174  SMITH            NaN  NaN
# 1855177  1831538214  7416241500  I20160812000332    ZHU            NaN  NaN
# 2160250  1972774446  2062591282  I20080429000844  JIANG            NaN  NaN
#
#         gndr cred                                            med_sch  grd_yr  \
# 80900      F  NaN                                              OTHER  1997.0
# 80901      F  NaN                                              OTHER  1997.0
# 80902      F  NaN                                              OTHER  1997.0
# 128852     F  NaN          LAKE ERIE COLLEGE OF OSTEOPATHIC MEDICINE  2014.0
# 500235     F  NaN          UNIVERSITY OF MARYLAND SCHOOL OF MEDICINE  2009.0
# 500236     F  NaN          UNIVERSITY OF MARYLAND SCHOOL OF MEDICINE  2009.0
# 500237     F  NaN          UNIVERSITY OF MARYLAND SCHOOL OF MEDICINE  2009.0
# 885207     F  NaN  JEFFERSON MEDICAL COLLEGE OF THOMAS JEFFERSON ...  2007.0
# 1138928    F  NaN                                              OTHER  1994.0
# 1141501    F  NaN                                              OTHER  2011.0
# 1141502    F  NaN                                              OTHER  2011.0
# 1304346    F  NaN                                              OTHER  1994.0
# 1428411    F  NaN                                              OTHER  1998.0
# 1428412    F  NaN                                              OTHER  1998.0
# 1428413    F  NaN                                              OTHER  1998.0
# 1428414    F  NaN                                              OTHER  1998.0
# 1428415    F  NaN                                              OTHER  1998.0
# 1428416    F  NaN                                              OTHER  1998.0
# 1693799    F  NaN                                              OTHER  2005.0
# 1744769    F  NaN                                              OTHER  1998.0
# 1744770    F  NaN                                              OTHER  1998.0
# 1802680    F  NaN                                              OTHER  2016.0
# 1855177    F  NaN                                              OTHER  2005.0
# 2160250    F  NaN                                              OTHER  1992.0
#
#                     pri_spec         sec_spec_1 sec_spec_2 sec_spec_3  \
# 80900          OPHTHALMOLOGY                NaN        NaN        NaN
# 80901          OPHTHALMOLOGY                NaN        NaN        NaN
# 80902          OPHTHALMOLOGY                NaN        NaN        NaN
# 128852       FAMILY MEDICINE                NaN        NaN        NaN
# 500235         ENDOCRINOLOGY                NaN        NaN        NaN
# 500236         ENDOCRINOLOGY                NaN        NaN        NaN
# 500237         ENDOCRINOLOGY                NaN        NaN        NaN
# 885207        ANESTHESIOLOGY                NaN        NaN        NaN
# 1138928  HEMATOLOGY/ONCOLOGY  INTERNAL MEDICINE        NaN        NaN
# 1141501      FAMILY MEDICINE                NaN        NaN        NaN
# 1141502      FAMILY MEDICINE                NaN        NaN        NaN
# 1304346          HOSPITALIST  INTERNAL MEDICINE        NaN        NaN
# 1428411     GASTROENTEROLOGY                NaN        NaN        NaN
# 1428412     GASTROENTEROLOGY                NaN        NaN        NaN
# 1428413     GASTROENTEROLOGY                NaN        NaN        NaN
# 1428414     GASTROENTEROLOGY                NaN        NaN        NaN
# 1428415     GASTROENTEROLOGY                NaN        NaN        NaN
# 1428416     GASTROENTEROLOGY                NaN        NaN        NaN
# 1693799       ANESTHESIOLOGY    PAIN MANAGEMENT        NaN        NaN
# 1744769    INTERNAL MEDICINE                NaN        NaN        NaN
# 1744770    INTERNAL MEDICINE                NaN        NaN        NaN
# 1802680   RADIATION ONCOLOGY                NaN        NaN        NaN
# 1855177    INTERNAL MEDICINE                NaN        NaN        NaN
# 2160250    INTERNAL MEDICINE                NaN        NaN        NaN
#
#         sec_spec_4       sec_spec_all  \
# 80900          NaN                NaN
# 80901          NaN                NaN
# 80902          NaN                NaN
# 128852         NaN                NaN
# 500235         NaN                NaN
# 500236         NaN                NaN
# 500237         NaN                NaN
# 885207         NaN                NaN
# 1138928        NaN  INTERNAL MEDICINE
# 1141501        NaN                NaN
# 1141502        NaN                NaN
# 1304346        NaN  INTERNAL MEDICINE
# 1428411        NaN                NaN
# 1428412        NaN                NaN
# 1428413        NaN                NaN
# 1428414        NaN                NaN
# 1428415        NaN                NaN
# 1428416        NaN                NaN
# 1693799        NaN    PAIN MANAGEMENT
# 1744769        NaN                NaN
# 1744770        NaN                NaN
# 1802680        NaN                NaN
# 1855177        NaN                NaN
# 2160250        NaN                NaN
#
#                                        org_lgl_nm    org_pac_id  num_org_mem  \
# 80900                                         NaN           NaN          NaN
# 80901                      EVERGREEN MEDICAL PLLC  1.355539e+09          8.0
# 80902    CONEY ISLAND MEDICAL PRACTICE PLAN, P.C.  5.496945e+09        284.0
# 128852            HIGH DESERT MEDICAL CORPORATION  6.103731e+09         70.0
# 500235                                 UC REGENTS  1.355249e+09        841.0
# 500236                                 UC REGENTS  1.355249e+09        841.0
# 500237                                 UC REGENTS  1.355249e+09        841.0
# 885207         PHYSICIANS ANESTHESIA SERVICE PLLC  6.901792e+09        151.0
# 1138928          ST MARYS REGIONAL MEDICAL CENTER  4.210712e+07        186.0
# 1141501             BAYLOR ST LUKES MEDICAL GROUP  9.133213e+09        256.0
# 1141502             BAYLOR ST LUKES MEDICAL GROUP  9.133213e+09        256.0
# 1304346                  NOVANT MEDICAL GROUP INC  1.153235e+09       1737.0
# 1428411                OSU INTERNAL MEDICINE, LLC  5.496651e+09        750.0
# 1428412                OSU INTERNAL MEDICINE, LLC  5.496651e+09        750.0
# 1428413                OSU INTERNAL MEDICINE, LLC  5.496651e+09        750.0
# 1428414                OSU INTERNAL MEDICINE, LLC  5.496651e+09        750.0
# 1428415                OSU INTERNAL MEDICINE, LLC  5.496651e+09        750.0
# 1428416                OSU INTERNAL MEDICINE, LLC  5.496651e+09        750.0
# 1693799      PHYSICIANS OF UNIVERSITY HOSPITAL PC  5.890878e+09        393.0
# 1744769                 MARIN HEALTHCARE DISTRICT  5.698818e+09         59.0
# 1744770           REGENTS UNIV OF CALIFORNIA UCSF  6.305160e+09        127.0
# 1802680                               MAYO CLINIC  6.507778e+09       4126.0
# 1855177                         ARNETT CLINIC LLC  7.491844e+08        324.0
# 2160250               THE VANCOUVER CLINIC INC PS  3.173436e+09        334.0
#
#                        adr_ln_1                             adr_ln_2  \
# 80900             9 MAC LEAN DR                                  NaN
# 80901                  755 -759                                  NaN
# 80902           2601 OCEAN PKWY                                  NaN
# 128852        43839 N 15TH ST W                                  NaN
# 500235   2020 SANTA MONICA BLVD                                  NaN
# 500236   2020 SANTA MONICA BLVD                            SUITE 240
# 500237        6633 TELEPHONE RD                                  NaN
# 885207          1229 MADISON ST                           SUITE 1440
# 1138928           93 CAMPUS AVE                                  NaN
# 1141501             210 LAKE RD                                  NaN
# 1141502        120 FLAG LAKE DR                              SUITE 1
# 1304346   3333 SILAS CREEK PKWY                                  NaN
# 1428411      3900 STONERIDGE LN                                  NaN
# 1428412      480 MEDICAL CTR DR                         DAVIS CENTER
# 1428413    480 W MEDICAL CTR DR       OSU MEDICAL CENTER DODD CENTER
# 1428414          410 W 10TH AVE                   OSU MEDICAL CENTER
# 1428415          452 W 10TH AVE                  ROSS HEART HOSPITAL
# 1428416          460 W 10TH AVE  OSU INTERNAL MEDICINE THE NEW JAMES
# 1693799         475 SEAVIEW AVE                                  NaN
# 1744769          75 ROWLAND WAY                                  NaN
# 1744770       505 PARNASSUS AVE                                  NaN
# 1802680           200 1ST ST SW                                  NaN
# 1855177       2600 GREENBUSH ST                                  NaN
# 2160250         700 NE 87TH AVE                                  NaN
#
#         ln_2_sprs            cty  st        zip     phn_numbr hosp_afl_1  \
# 80900         NaN      GLEN HEAD  NY  115453137           NaN     330193
# 80901         NaN       BROOKLYN  NY  112204211  7.186809e+09     330193
# 80902         NaN       BROOKLYN  NY  112357745  7.186165e+09     330193
# 128852        NaN      LANCASTER  CA  935344756  6.619456e+09        NaN
# 500235        NaN   SANTA MONICA  CA  904042023  3.104582e+09      50262
# 500236        NaN   SANTA MONICA  CA  904042023  3.105826e+09      50262
# 500237          Y        VENTURA  CA  930035569  8.056428e+09      50262
# 885207        NaN        SEATTLE  WA  981043538  2.066251e+09     500025
# 1138928       NaN       LEWISTON  ME   42406030  2.077774e+09     200034
# 1141501         Y   LAKE JACKSON  TX  775664982  7.137982e+10     450072
# 1141502       NaN   LAKE JACKSON  TX  775666292  7.137982e+10     450072
# 1304346       NaN  WINSTON SALEM  NC  271033013  3.367189e+09     340014
# 1428411       NaN         DUBLIN  OH  430172288  6.148895e+09     360085
# 1428412       NaN       COLUMBUS  OH  432101229  6.142935e+09     360085
# 1428413       NaN       COLUMBUS  OH  432101229  6.142935e+09     360085
# 1428414       NaN       COLUMBUS  OH  432101240  6.142938e+09     360085
# 1428415       NaN       COLUMBUS  OH  432101240  6.142934e+09     360085
# 1428416       NaN       COLUMBUS  OH  432101240  6.142939e+09     360085
# 1693799       NaN  STATEN ISLAND  NY  103053436  7.182269e+09     330160
# 1744769         Y         NOVATO  CA  949455054           NaN     050131
# 1744770       NaN  SAN FRANCISCO  CA  941432204  4.154761e+09     050131
# 1802680       NaN      ROCHESTER  MN  559050001  5.072843e+09     240010
# 1855177       NaN      LAFAYETTE  IN  479042477  7.654488e+09     150173
# 2160250       NaN      VANCOUVER  WA  986641913  3.608823e+09     500050
#
#                                     hosp_afl_lbn_1 hosp_afl_2  \
# 80900             FLUSHING HOSPITAL MEDICAL CENTER        NaN
# 80901             FLUSHING HOSPITAL MEDICAL CENTER        NaN
# 80902             FLUSHING HOSPITAL MEDICAL CENTER        NaN
# 128852                                         NaN        NaN
# 500235        RONALD REAGAN U C L A MEDICAL CENTER      50549
# 500236        RONALD REAGAN U C L A MEDICAL CENTER      50549
# 500237        RONALD REAGAN U C L A MEDICAL CENTER      50549
# 885207        SWEDISH MEDICAL CENTER / CHERRY HILL     500027
# 1138928           ST MARYS REGIONAL MEDICAL CENTER        NaN
# 1141501         CHI ST. LUKES' BRAZOSPORT HOSPITAL     450018
# 1141502         CHI ST. LUKES' BRAZOSPORT HOSPITAL     450018
# 1304346       NOVANT HEALTH FORSYTH MEDICAL CENTER        NaN
# 1428411  OHIO STATE UNIVERSITY STATE HEALTH SYSTEM     360242
# 1428412  OHIO STATE UNIVERSITY STATE HEALTH SYSTEM     360242
# 1428413  OHIO STATE UNIVERSITY STATE HEALTH SYSTEM     360242
# 1428414  OHIO STATE UNIVERSITY STATE HEALTH SYSTEM     360242
# 1428415  OHIO STATE UNIVERSITY STATE HEALTH SYSTEM     360242
# 1428416  OHIO STATE UNIVERSITY STATE HEALTH SYSTEM     360242
# 1693799          STATEN ISLAND UNIVERSITY HOSPITAL        NaN
# 1744769                  NOVATO COMMUNITY HOSPITAL      50360
# 1744770                  NOVATO COMMUNITY HOSPITAL      50360
# 1802680             MAYO CLINIC HOSPITAL ROCHESTER        NaN
# 1855177  INDIANA UNIVERSITY HEALTH ARNETT HOSPITAL     150056
# 2160250       PEACEHEALTH SOUTHWEST MEDICAL CENTER        NaN
#
#                                             hosp_afl_lbn_2 hosp_afl_3  \
# 80900                                                  NaN        NaN
# 80901                                                  NaN        NaN
# 80902                                                  NaN        NaN
# 128852                                                 NaN        NaN
# 500235                LOS ROBLES HOSPITAL & MEDICAL CENTER        NaN
# 500236                LOS ROBLES HOSPITAL & MEDICAL CENTER        NaN
# 500237                LOS ROBLES HOSPITAL & MEDICAL CENTER        NaN
# 885207         SWEDISH MEDICAL CENTER - FIRST HILL/BALLARD        NaN
# 1138928                                                NaN        NaN
# 1141501       UNIVERSITY OF TEXAS MEDICAL BRANCH GALVESTON        NaN
# 1141502       UNIVERSITY OF TEXAS MEDICAL BRANCH GALVESTON        NaN
# 1304346                                                NaN        NaN
# 1428411  JAMES CANCER HOSPITAL & SOLOVE RESEARCH INSTITUTE        NaN
# 1428412  JAMES CANCER HOSPITAL & SOLOVE RESEARCH INSTITUTE        NaN
# 1428413  JAMES CANCER HOSPITAL & SOLOVE RESEARCH INSTITUTE        NaN
# 1428414  JAMES CANCER HOSPITAL & SOLOVE RESEARCH INSTITUTE        NaN
# 1428415  JAMES CANCER HOSPITAL & SOLOVE RESEARCH INSTITUTE        NaN
# 1428416  JAMES CANCER HOSPITAL & SOLOVE RESEARCH INSTITUTE        NaN
# 1693799                                                NaN        NaN
# 1744769                             MARIN GENERAL HOSPITAL        NaN
# 1744770                             MARIN GENERAL HOSPITAL        NaN
# 1802680                                                NaN        NaN
# 1855177  INDIANA UNIVERSITY HEALTH METHODIST HOSPITAL (...        NaN
# 2160250                                                NaN        NaN
#
#         hosp_afl_lbn_3 hosp_afl_4 hosp_afl_lbn_4  hosp_afl_5 hosp_afl_lbn_5  \
# 80900              NaN        NaN            NaN         NaN            NaN
# 80901              NaN        NaN            NaN         NaN            NaN
# 80902              NaN        NaN            NaN         NaN            NaN
# 128852             NaN        NaN            NaN         NaN            NaN
# 500235             NaN        NaN            NaN         NaN            NaN
# 500236             NaN        NaN            NaN         NaN            NaN
# 500237             NaN        NaN            NaN         NaN            NaN
# 885207             NaN        NaN            NaN         NaN            NaN
# 1138928            NaN        NaN            NaN         NaN            NaN
# 1141501            NaN        NaN            NaN         NaN            NaN
# 1141502            NaN        NaN            NaN         NaN            NaN
# 1304346            NaN        NaN            NaN         NaN            NaN
# 1428411            NaN        NaN            NaN         NaN            NaN
# 1428412            NaN        NaN            NaN         NaN            NaN
# 1428413            NaN        NaN            NaN         NaN            NaN
# 1428414            NaN        NaN            NaN         NaN            NaN
# 1428415            NaN        NaN            NaN         NaN            NaN
# 1428416            NaN        NaN            NaN         NaN            NaN
# 1693799            NaN        NaN            NaN         NaN            NaN
# 1744769            NaN        NaN            NaN         NaN            NaN
# 1744770            NaN        NaN            NaN         NaN            NaN
# 1802680            NaN        NaN            NaN         NaN            NaN
# 1855177            NaN        NaN            NaN         NaN            NaN
# 2160250            NaN        NaN            NaN         NaN            NaN
#
#         assgn
# 80900       Y
# 80901       Y
# 80902       Y
# 128852      Y
# 500235      Y
# 500236      Y
# 500237      Y
# 885207      Y
# 1138928     Y
# 1141501     Y
# 1141502     Y
# 1304346     Y
# 1428411     Y
# 1428412     Y
# 1428413     Y
# 1428414     Y
# 1428415     Y
# 1428416     Y
# 1693799     Y
# 1744769     M
# 1744770     M
# 1802680     Y
# 1855177     Y
# 2160250     Y

# %% [markdown]
# Due to the number of observations being so low for `lst_nm` and `frst_nm` - 37 and 24, respectively - compared to the overall data set, a good tactic might be to drop them. However, when we look at the observations, they still have value as there is information regarding the school attended, year graduated, specialty, etc. so dropping them might not be the best idea. Plus none of them are missing their professional enrollment ID, so what should we do?
#
# Let's assign a value of `missing` as a string to any observation that does not have a first or last name. This will allow us to keep the rest of the data for the observations while also affirming that there is incomplete information regarding exactly who this physician is.

# %%
# place "" with "missing" in both first and last name
data[['lst_nm', 'frst_nm']] = data[['lst_nm', 'frst_nm']].replace("", "Missing")

# %%
# example of missing first name and how it was replaced (look at frst_nm)
data.iloc[80900]
# Out:
# npi                                     1033381983
# ind_pac_id                              4183808488
# ind_enrl_id                        I20110412000132
# lst_nm                                          MA
# frst_nm                                    Missing
# mid_nm                                         NaN
# suff                                           NaN
# gndr                                             F
# cred                                           NaN
# med_sch                                      OTHER
# grd_yr                                        1997
# pri_spec                             OPHTHALMOLOGY
# sec_spec_1                                     NaN
# sec_spec_2                                     NaN
# sec_spec_3                                     NaN
# sec_spec_4                                     NaN
# sec_spec_all                                   NaN
# org_lgl_nm                                     NaN
# org_pac_id                                     NaN
# num_org_mem                                    NaN
# adr_ln_1                             9 MAC LEAN DR
# adr_ln_2                                       NaN
# ln_2_sprs                                      NaN
# cty                                      GLEN HEAD
# st                                              NY
# zip                                      115453137
# phn_numbr                                      NaN
# hosp_afl_1                                  330193
# hosp_afl_lbn_1    FLUSHING HOSPITAL MEDICAL CENTER
# hosp_afl_2                                     NaN
# hosp_afl_lbn_2                                 NaN
# hosp_afl_3                                     NaN
# hosp_afl_lbn_3                                 NaN
# hosp_afl_4                                     NaN
# hosp_afl_lbn_4                                 NaN
# hosp_afl_5                                     NaN
# hosp_afl_lbn_5                                 NaN
# assgn                                            Y
# Name: 80900, dtype: object

# %%
# example of missing last name and how it was replaced (look at lst_nm)
data.iloc[136176]
# Out:
# npi                    1063454130
# ind_pac_id             8628071131
# ind_enrl_id       I20060822000324
# lst_nm                    Missing
# frst_nm                  BENJAMIN
# mid_nm                     HANBOK
# suff                          NaN
# gndr                            M
# cred                           OD
# med_sch                     OTHER
# grd_yr                       2001
# pri_spec                OPTOMETRY
# sec_spec_1                    NaN
# sec_spec_2                    NaN
# sec_spec_3                    NaN
# sec_spec_4                    NaN
# sec_spec_all                  NaN
# org_lgl_nm                    NaN
# org_pac_id                    NaN
# num_org_mem                   NaN
# adr_ln_1           115 W 25TH AVE
# adr_ln_2                      NaN
# ln_2_sprs                     NaN
# cty                     SAN MATEO
# st                             CA
# zip                     944032259
# phn_numbr              6.5035e+09
# hosp_afl_1                    NaN
# hosp_afl_lbn_1                NaN
# hosp_afl_2                    NaN
# hosp_afl_lbn_2                NaN
# hosp_afl_3                    NaN
# hosp_afl_lbn_3                NaN
# hosp_afl_4                    NaN
# hosp_afl_lbn_4                NaN
# hosp_afl_5                    NaN
# hosp_afl_lbn_5                NaN
# assgn                           Y
# Name: 136176, dtype: object

# %% [markdown]
# The next name related issues we have to address has to do with the middle name and suffix.

# %%
data[['mid_nm', 'suff']].isna().mean()
# Out:
# mid_nm    0.245823
# suff      0.981644
# dtype: float64

# %% [markdown]
# Let's do what we did before and replace `NaN` in these columns with a blank `""`.

# %%
# fill nan with ""
data[['mid_nm', 'suff']] = data[['mid_nm', 'suff']].fillna(value="")

# %%
# check to see percentage of nan in middle name and suffix columns
data[['mid_nm', 'suff']].isna().mean()
# Out:
# mid_nm    0.0
# suff      0.0
# dtype: float64

# %%
# check percentage of nan in all name related columns
data[['lst_nm', 'frst_nm', 'mid_nm', 'suff']].isna().mean()
# Out:
# lst_nm     0.0
# frst_nm    0.0
# mid_nm     0.0
# suff       0.0
# dtype: float64

# %% [markdown]
# Ok cool now what we're going to do is combine all four of these columns into one to see if it might help us address the difference in unique IDs and names.

# %%
# %%timeit
# data[['frst_nm', 'mid_nm', 'lst_nm', 'suff']].apply(lambda x: ' '.join(x.astype(str)), axis=1)

# %%
# %%timeit
data['frst_nm'].astype(str) + ' ' + data['mid_nm'].astype(str) + ' ' + data['lst_nm'].astype(str) + ' ' + data['suff'].astype(str)
# Out:
# 1.63 s ± 308 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# create column of full names
data['full_nm'] = data['frst_nm'].astype(str) + ' ' + data['mid_nm'].astype(str) + ' ' + data['lst_nm'].astype(str) + ' ' + data['suff'].astype(str)

# %%
# see the first 10 full names
data['full_nm'][:10]
# Out:
# 0    ARDALAN  ENKESHAFI
# 1    ARDALAN  ENKESHAFI
# 2    ARDALAN  ENKESHAFI
# 3    ARDALAN  ENKESHAFI
# 4    ARDALAN  ENKESHAFI
# 5       THOMAS L CIBULL
# 6       THOMAS L CIBULL
# 7       THOMAS L CIBULL
# 8       THOMAS L CIBULL
# 9       THOMAS L CIBULL
# Name: full_nm, dtype: object

# %% [markdown]
# Ok so we've combined all the name information into one column. Let's see if it helps us at all when it comes to identifying where there is fewer names than IDs.

# %%
# return the total number of unique full names
len(data['full_nm'].unique())
# Out:
# 1072060

# %% [markdown]
# Ok it looks like this helped increase the number of unique names! It is still less than the total number of unique IDs though as we can see below:

# %%
# see how many unique professional enrollment ID numbers there are
len(data['ind_enrl_id'].unique())
# Out:
# 1147121

# %%
1147121 - 1072060
# Out:
# 75061

# %% [markdown]
# However, the gap is not nearly as large as it was before which is a good thing. We still need to keep digging though to determine why there is this discrepency.

# %%
data[['full_nm', 'ind_enrl_id']].head()
# Out:
#                full_nm      ind_enrl_id
# 0  ARDALAN  ENKESHAFI   I20130530000085
# 1  ARDALAN  ENKESHAFI   I20130530000085
# 2  ARDALAN  ENKESHAFI   I20150824000105
# 3  ARDALAN  ENKESHAFI   I20150824000105
# 4  ARDALAN  ENKESHAFI   I20150824000105

# %% [markdown]
# Luckily we don't have to look too hard as the first five rows shows us that the same physician can have multiple IDs. I hypothesize that this has to do with the primary specialty and any other secondary specialties a physician may have.

# %%
data.head(10)
# Out:
#           npi  ind_pac_id      ind_enrl_id     lst_nm  frst_nm mid_nm suff  \
# 0  1003000126  7517003643  I20130530000085  ENKESHAFI  ARDALAN
# 1  1003000126  7517003643  I20130530000085  ENKESHAFI  ARDALAN
# 2  1003000126  7517003643  I20150824000105  ENKESHAFI  ARDALAN
# 3  1003000126  7517003643  I20150824000105  ENKESHAFI  ARDALAN
# 4  1003000126  7517003643  I20150824000105  ENKESHAFI  ARDALAN
# 5  1003000134  4284706367  I20080707000385     CIBULL   THOMAS      L
# 6  1003000134  4284706367  I20080707000385     CIBULL   THOMAS      L
# 7  1003000134  4284706367  I20080707000385     CIBULL   THOMAS      L
# 8  1003000134  4284706367  I20080707000385     CIBULL   THOMAS      L
# 9  1003000134  4284706367  I20080707000385     CIBULL   THOMAS      L
#
#   gndr cred                                     med_sch  grd_yr  \
# 0    M  NaN                                       OTHER  1994.0
# 1    M  NaN                                       OTHER  1994.0
# 2    M  NaN                                       OTHER  1994.0
# 3    M  NaN                                       OTHER  1994.0
# 4    M  NaN                                       OTHER  1994.0
# 5    M  NaN  UNIVERSITY OF KENTUCKY COLLEGE OF MEDICINE  2003.0
# 6    M  NaN  UNIVERSITY OF KENTUCKY COLLEGE OF MEDICINE  2003.0
# 7    M  NaN  UNIVERSITY OF KENTUCKY COLLEGE OF MEDICINE  2003.0
# 8    M  NaN  UNIVERSITY OF KENTUCKY COLLEGE OF MEDICINE  2003.0
# 9    M  NaN  UNIVERSITY OF KENTUCKY COLLEGE OF MEDICINE  2003.0
#
#             pri_spec sec_spec_1 sec_spec_2 sec_spec_3 sec_spec_4 sec_spec_all  \
# 0  INTERNAL MEDICINE        NaN        NaN        NaN        NaN          NaN
# 1  INTERNAL MEDICINE        NaN        NaN        NaN        NaN          NaN
# 2  INTERNAL MEDICINE        NaN        NaN        NaN        NaN          NaN
# 3  INTERNAL MEDICINE        NaN        NaN        NaN        NaN          NaN
# 4  INTERNAL MEDICINE        NaN        NaN        NaN        NaN          NaN
# 5          PATHOLOGY        NaN        NaN        NaN        NaN          NaN
# 6          PATHOLOGY        NaN        NaN        NaN        NaN          NaN
# 7          PATHOLOGY        NaN        NaN        NaN        NaN          NaN
# 8          PATHOLOGY        NaN        NaN        NaN        NaN          NaN
# 9          PATHOLOGY        NaN        NaN        NaN        NaN          NaN
#
#                                           org_lgl_nm    org_pac_id  \
# 0                EMERGENCY MEDICINE ASSOCIATES PA PC  8.022915e+09
# 1                EMERGENCY MEDICINE ASSOCIATES PA PC  8.022915e+09
# 2                EMERGENCY MEDICINE ASSOCIATES PA PC  8.022915e+09
# 3               SOUTHEASTERN INTENSIVIST SERVICES PC  9.335152e+09
# 4               SOUTHEASTERN INTENSIVIST SERVICES PC  9.335152e+09
# 5  NORTHSHORE UNIVERSITY HEALTHSYSTEM FACULTY PRA...  2.163335e+09
# 6  NORTHSHORE UNIVERSITY HEALTHSYSTEM FACULTY PRA...  2.163335e+09
# 7  NORTHSHORE UNIVERSITY HEALTHSYSTEM FACULTY PRA...  2.163335e+09
# 8  NORTHSHORE UNIVERSITY HEALTHSYSTEM FACULTY PRA...  2.163335e+09
# 9  NORTHSHORE UNIVERSITY HEALTHSYSTEM FACULTY PRA...  2.163335e+09
#
#    num_org_mem                     adr_ln_1 adr_ln_2 ln_2_sprs  \
# 0        182.0           1850 TOWN CTR PKWY      NaN       NaN
# 1        182.0       1701 N GEORGE MASON DR      NaN       NaN
# 2        182.0     24440 STONE SPRINGS BLVD      NaN       NaN
# 3        133.0      1401 JOHNSTON WILLIS DR      NaN       NaN
# 4        133.0            411 W RANDOLPH RD      NaN       NaN
# 5       1286.0            2100 PFINGSTEN RD      NaN       NaN
# 6       1286.0  2180 PFINGSTEN RD 1ST FLOOR      NaN         Y
# 7       1286.0               777 PARK W AVE      NaN       NaN
# 8       1286.0               777 PARK AVE W      NaN         Y
# 9       1286.0          9600 GROSS POINT RD      NaN       NaN
#
#                   cty  st        zip     phn_numbr hosp_afl_1  \
# 0              RESTON  VA  201903219  7.036899e+09     490112
# 1           ARLINGTON  VA  222053610  7.035586e+09     490112
# 2              DULLES  VA  201662247  5.713674e+09     490112
# 3  NORTH CHESTERFIELD  VA  232354730  8.044835e+09     490112
# 4            HOPEWELL  VA  238602938  8.045412e+09     490112
# 5            GLENVIEW  IL  600261301           NaN     140010
# 6            GLENVIEW  IL  600261301           NaN     140010
# 7       HIGHLAND PARK  IL  600352433  8.474328e+09     140010
# 8       HIGHALND PARK  IL  600352433           NaN     140010
# 9              SKOKIE  IL  600761214           NaN     140010
#
#                                       hosp_afl_lbn_1 hosp_afl_2  \
# 0                                 CJW MEDICAL CENTER     210028
# 1                                 CJW MEDICAL CENTER     210028
# 2                                 CJW MEDICAL CENTER     210028
# 3                                 CJW MEDICAL CENTER     210028
# 4                                 CJW MEDICAL CENTER     210028
# 5  NORTHSHORE UNIVERSITY HEALTHSYSTEM - EVANSTON ...        NaN
# 6  NORTHSHORE UNIVERSITY HEALTHSYSTEM - EVANSTON ...        NaN
# 7  NORTHSHORE UNIVERSITY HEALTHSYSTEM - EVANSTON ...        NaN
# 8  NORTHSHORE UNIVERSITY HEALTHSYSTEM - EVANSTON ...        NaN
# 9  NORTHSHORE UNIVERSITY HEALTHSYSTEM - EVANSTON ...        NaN
#
#                   hosp_afl_lbn_2 hosp_afl_3 hosp_afl_lbn_3 hosp_afl_4  \
# 0  MEDSTAR SAINT MARY'S HOSPITAL        NaN            NaN        NaN
# 1  MEDSTAR SAINT MARY'S HOSPITAL        NaN            NaN        NaN
# 2  MEDSTAR SAINT MARY'S HOSPITAL        NaN            NaN        NaN
# 3  MEDSTAR SAINT MARY'S HOSPITAL        NaN            NaN        NaN
# 4  MEDSTAR SAINT MARY'S HOSPITAL        NaN            NaN        NaN
# 5                            NaN        NaN            NaN        NaN
# 6                            NaN        NaN            NaN        NaN
# 7                            NaN        NaN            NaN        NaN
# 8                            NaN        NaN            NaN        NaN
# 9                            NaN        NaN            NaN        NaN
#
#   hosp_afl_lbn_4  hosp_afl_5 hosp_afl_lbn_5 assgn              full_nm
# 0            NaN         NaN            NaN     Y  ARDALAN  ENKESHAFI
# 1            NaN         NaN            NaN     Y  ARDALAN  ENKESHAFI
# 2            NaN         NaN            NaN     Y  ARDALAN  ENKESHAFI
# 3            NaN         NaN            NaN     Y  ARDALAN  ENKESHAFI
# 4            NaN         NaN            NaN     Y  ARDALAN  ENKESHAFI
# 5            NaN         NaN            NaN     Y     THOMAS L CIBULL
# 6            NaN         NaN            NaN     Y     THOMAS L CIBULL
# 7            NaN         NaN            NaN     Y     THOMAS L CIBULL
# 8            NaN         NaN            NaN     Y     THOMAS L CIBULL
# 9            NaN         NaN            NaN     Y     THOMAS L CIBULL

# %% [markdown]
# The first three columns - `npi`, `ind_pac_id`, and `ind_enrl_id` - provide us information regarding that particular physician's ID assigned by NPPES, PECOS, and for individual professional enrollment (which is the course for the data in that particular observation). All three are different, and we can see that for the first two physicians listed - `ENKESHAFI ARDALAN` and `CIBULL THOMAS` - that their `npi` and `ind_pac_id` are the same for all observations. However, when we look to `ENKESHAFI ARDALAN` we can see that there are two unique `ind_enrl_id`s: `I20130530000085` & `I20150824000105`.
#
# I think I'm going to have to do a little bit more research about what exactly is going on with `ind_pac_id`. Since we haven't really done any exploration on the other two IDs, let's see if either might serve as a better unique identifier.

# %%
# see how many unqiue observations are in NPI id column
len(data['npi'].unique())
# Out:
# 1103330

# %%
# see how many unique observations are in PAC ID column
len(data['ind_pac_id'].unique())
# Out:
# 1103330

# %% [markdown]
# As we can see above, both have the same number of unique IDs. However, there are still more unique values than there are unique names - _1,103,330_ versus _1,072,060_, respectively. This is something I'm very intrigued by but for now let's shelve it and start exploring other facets of the data. The next two columns that catch my eye are the `med_sch` and `grd_yr` columns (i.e. medical school physician attended and their graduation year).

# %%
# lets see what data types we are dealing with, starting with med_sch
print('Data type for the med_sch column: {}'.format(data['med_sch'].dtype))
print('Total number of unique values in the med_sch column: {}'.format(len(data['med_sch'].unique())))
# Out:
# Data type for the med_sch column: object
# Total number of unique values in the med_sch column: 401

# %% [markdown]
# So we're working with string values, and `401` unique schools. As a proxy to best address duplicate entries (as we saw, the same physican can have multiple rows thus inflating the number of instances of his/her school) we'll group by `npi` and then see the breakdown by school.

# %%
# ensure that when we group by NPI 
len(data.groupby('npi')['med_sch'].first())
# Out:
# 1103330

# %%
# lets see what it looks like as a pandas DataFrame
pd.DataFrame(data.groupby('npi')['med_sch'].first()).head()
# Out:
#                                                med_sch
# npi
# 1003000126                                       OTHER
# 1003000134  UNIVERSITY OF KENTUCKY COLLEGE OF MEDICINE
# 1003000142                                       OTHER
# 1003000423                      TOLEDO MEDICAL COLLEGE
# 1003000480   OHIO STATE UNIVERSITY COLLEGE OF MEDICINE

# %% [markdown]
# I like what I'm seeing! Let's go ahead and create a `pandas` DataFrame from this so that we can analyze it further.

# %%
# create school count dataframe
school_count = pd.DataFrame(data.groupby('npi')['med_sch'].first()); school_count.head()
# Out:
#                                                med_sch
# npi
# 1003000126                                       OTHER
# 1003000134  UNIVERSITY OF KENTUCKY COLLEGE OF MEDICINE
# 1003000142                                       OTHER
# 1003000423                      TOLEDO MEDICAL COLLEGE
# 1003000480   OHIO STATE UNIVERSITY COLLEGE OF MEDICINE

# %%
# reset the index to make npi its own column
school_count = school_count.reset_index(); school_count.head()
# Out:
#           npi                                     med_sch
# 0  1003000126                                       OTHER
# 1  1003000134  UNIVERSITY OF KENTUCKY COLLEGE OF MEDICINE
# 2  1003000142                                       OTHER
# 3  1003000423                      TOLEDO MEDICAL COLLEGE
# 4  1003000480   OHIO STATE UNIVERSITY COLLEGE OF MEDICINE

# %%
# let's get the value counts now for the schools, displaying only the top 10
school_count['med_sch'].value_counts()[:10]
# Out:
# OTHER                                                       589730
# INDIANA UNIVERSITY SCHOOL OF MEDICINE                         7375
# WAYNE STATE UNIVERSITY SCHOOL OF MEDICINE                     7297
# PALMER COLLEGE CHIROPRACTIC - DAVENPORT                       6849
# PHILADELPHIA COLLEGE OF OSTEOPATHIC MEDICINE                  6236
# UNIVERSITY OF MINNESOTA MEDICAL SCHOOL                        6201
# TEMPLE UNIVERSITY SCHOOL OF MEDICINE                          5986
# OHIO STATE UNIVERSITY COLLEGE OF MEDICINE                     5986
# UNIVERSITY OF ILLINOIS AT CHICAGO HEALTH SCIENCE CENTER       5665
# JEFFERSON MEDICAL COLLEGE OF THOMAS JEFFERSON UNIVERSITY      5415
# Name: med_sch, dtype: int64

# %% [markdown]
# Looks like other is the overwhelming majority of observations! To get a better idea of the distribution, let's use percentages in place of absolute counts.

# %%
# normalize counts so it returns a percentage
round((school_count['med_sch'].value_counts(normalize=True) * 100), 3)[:10]
# Out:
# OTHER                                                       53.450
# INDIANA UNIVERSITY SCHOOL OF MEDICINE                        0.668
# WAYNE STATE UNIVERSITY SCHOOL OF MEDICINE                    0.661
# PALMER COLLEGE CHIROPRACTIC - DAVENPORT                      0.621
# PHILADELPHIA COLLEGE OF OSTEOPATHIC MEDICINE                 0.565
# UNIVERSITY OF MINNESOTA MEDICAL SCHOOL                       0.562
# TEMPLE UNIVERSITY SCHOOL OF MEDICINE                         0.543
# OHIO STATE UNIVERSITY COLLEGE OF MEDICINE                    0.543
# UNIVERSITY OF ILLINOIS AT CHICAGO HEALTH SCIENCE CENTER      0.513
# JEFFERSON MEDICAL COLLEGE OF THOMAS JEFFERSON UNIVERSITY     0.491
# Name: med_sch, dtype: float64

# %%
# let's look a little bit further down the list (and return to counts)
school_count['med_sch'].value_counts(normalize=False)[10:20]
# Out:
# NEW YORK MEDICAL COLLEGE                                     5390
# UNIVERSITY OF MICHIGAN MEDICAL SCHOOL                        5338
# GEORGETOWN UNIVERSITY OF MEDICINE                            5111
# UNIVERSITY OF ALABAMA SCHOOL OF MEDICINE                     4976
# UNIVERSITY OF KANSAS SCHOOL OF MEDICINE                      4896
# MEDICAL COLLEGE OF GEORGIA                                   4882
# UNIVERSITY OF TENNESSEE COLLEGE OF MEDICINE                  4823
# UNIVERSITY OF CINCINNATI COLLEGE OF MEDICINE                 4771
# UNIVERSITY OF TEXAS SOUTHWESTERN MEDICAL SCHOOL AT DALLAS    4708
# UNIVERSITY OF TEXAS MEDICAL BRANCH AT GALVESTON              4690
# Name: med_sch, dtype: int64

# %%
# a little bit further...
school_count['med_sch'].value_counts(normalize=False)[20:30]
# Out:
# NEW YORK UNIVERSITY SCHOOL OF MEDICINE                          4630
# UNIVERSITY OF WASHINGTON SCHOOL OF MEDICINE                     4524
# LOUISIANA STATE UNIVERSITY SCHOOL OF MEDICINE IN NEW ORLEANS    4483
# MEDICAL COLLEGE OF WISCONSIN                                    4471
# UNIVERSITY OF IOWA COLLEGE OF MEDICINE                          4410
# BAYLOR COLLEGE OF MEDICINE                                      4344
# UNIVERSITY OF WISCONSIN MEDICAL SCHOOL                          4262
# BOSTON UNIVERSITY SCHOOL OF MEDICINE                            4203
# NORTHWESTERN UNIVERSITY MEDICAL SCHOOL                          4168
# TUFTS UNIVERSITY SCHOOL OF MEDICINE                             4152
# Name: med_sch, dtype: int64

# %%
data.tail()
# Out:
#                 npi  ind_pac_id      ind_enrl_id     lst_nm   frst_nm mid_nm  \
# 2210785  1992999825   143414284  I20101102000933  DESCHENES  GEOFFREY      R
# 2210786  1992999825   143414284  I20101102000933  DESCHENES  GEOFFREY      R
# 2210787  1992999825   143414284  I20101102000933  DESCHENES  GEOFFREY      R
# 2210788  1992999825   143414284  I20101102000933  DESCHENES  GEOFFREY      R
# 2210789  1992999825   143414284  I20101102000933  DESCHENES  GEOFFREY      R
#
#         suff gndr cred                                            med_sch  \
# 2210785         M  NaN  JEFFERSON MEDICAL COLLEGE OF THOMAS JEFFERSON ...
# 2210786         M  NaN  JEFFERSON MEDICAL COLLEGE OF THOMAS JEFFERSON ...
# 2210787         M  NaN  JEFFERSON MEDICAL COLLEGE OF THOMAS JEFFERSON ...
# 2210788         M  NaN  JEFFERSON MEDICAL COLLEGE OF THOMAS JEFFERSON ...
# 2210789         M  NaN  JEFFERSON MEDICAL COLLEGE OF THOMAS JEFFERSON ...
#
#          grd_yr        pri_spec sec_spec_1 sec_spec_2 sec_spec_3 sec_spec_4  \
# 2210785  2005.0  OTOLARYNGOLOGY        NaN        NaN        NaN        NaN
# 2210786  2005.0  OTOLARYNGOLOGY        NaN        NaN        NaN        NaN
# 2210787  2005.0  OTOLARYNGOLOGY        NaN        NaN        NaN        NaN
# 2210788  2005.0  OTOLARYNGOLOGY        NaN        NaN        NaN        NaN
# 2210789  2005.0  OTOLARYNGOLOGY        NaN        NaN        NaN        NaN
#
#         sec_spec_all                     org_lgl_nm    org_pac_id  \
# 2210785          NaN  VIRGINIA MASON MEDICAL CENTER  9.830003e+09
# 2210786          NaN  VIRGINIA MASON MEDICAL CENTER  9.830003e+09
# 2210787          NaN  VIRGINIA MASON MEDICAL CENTER  9.830003e+09
# 2210788          NaN  VIRGINIA MASON MEDICAL CENTER  9.830003e+09
# 2210789          NaN  VIRGINIA MASON MEDICAL CENTER  9.830003e+09
#
#          num_org_mem                adr_ln_1                       adr_ln_2  \
# 2210785        776.0        19116 33RD AVE W        VIRGINIA MASON LYNNWOOD
# 2210786        776.0           925 SENECA ST        VIRGINIA MASON HOSPITAL
# 2210787        776.0            1100 9TH AVE                            NaN
# 2210788        776.0   4575 SANDPOINT WAY NE                            NaN
# 2210789        776.0  4575 SAND POINT WAY NE  108 VIRGINIA MASON SAND POINT
#
#         ln_2_sprs       cty  st        zip     phn_numbr hosp_afl_1  \
# 2210785       NaN  LYNNWOOD  WA  980364706  4.257128e+09     500005
# 2210786       NaN   SEATTLE  WA  981012742  2.062237e+09     500005
# 2210787       NaN   SEATTLE  WA  981012756           NaN     500005
# 2210788         Y   SEATTLE  WA  981053999  2.065258e+09     500005
# 2210789       NaN   SEATTLE  WA  981053999  2.065258e+09     500005
#
#                         hosp_afl_lbn_1 hosp_afl_2 hosp_afl_lbn_2 hosp_afl_3  \
# 2210785  VIRGINIA MASON MEDICAL CENTER        NaN            NaN        NaN
# 2210786  VIRGINIA MASON MEDICAL CENTER        NaN            NaN        NaN
# 2210787  VIRGINIA MASON MEDICAL CENTER        NaN            NaN        NaN
# 2210788  VIRGINIA MASON MEDICAL CENTER        NaN            NaN        NaN
# 2210789  VIRGINIA MASON MEDICAL CENTER        NaN            NaN        NaN
#
#         hosp_afl_lbn_3 hosp_afl_4 hosp_afl_lbn_4  hosp_afl_5 hosp_afl_lbn_5  \
# 2210785            NaN        NaN            NaN         NaN            NaN
# 2210786            NaN        NaN            NaN         NaN            NaN
# 2210787            NaN        NaN            NaN         NaN            NaN
# 2210788            NaN        NaN            NaN         NaN            NaN
# 2210789            NaN        NaN            NaN         NaN            NaN
#
#         assgn                full_nm
# 2210785     Y  GEOFFREY R DESCHENES
# 2210786     Y  GEOFFREY R DESCHENES
# 2210787     Y  GEOFFREY R DESCHENES
# 2210788     Y  GEOFFREY R DESCHENES
# 2210789     Y  GEOFFREY R DESCHENES

# %%
# slight modification to column order, adding full name after other name columns
new_order = ['npi', 'ind_pac_id', 'ind_enrl_id', 'lst_nm', 'frst_nm', 'mid_nm', 'suff', 'full_nm', 
             'gndr', 'cred', 'med_sch', 'grd_yr', 'pri_spec', 'sec_spec_1', 'sec_spec_2', 
             'sec_spec_3', 'sec_spec_4', 'sec_spec_all', 'org_lgl_nm', 'org_pac_id', 
             'num_org_mem', 'adr_ln_1', 'adr_ln_2', 'ln_2_sprs', 'cty', 'st', 'zip', 
             'phn_numbr', 'hosp_afl_1', 'hosp_afl_lbn_1', 'hosp_afl_2', 'hosp_afl_lbn_2', 
             'hosp_afl_3', 'hosp_afl_lbn_3', 'hosp_afl_4', 'hosp_afl_lbn_4', 'hosp_afl_5', 
             'hosp_afl_lbn_5', 'assgn']

# assign new column order to data
data = data[new_order]

# %%
# check it to make sure it worked
data.head()
# Out:
#           npi  ind_pac_id      ind_enrl_id     lst_nm  frst_nm mid_nm suff  \
# 0  1003000126  7517003643  I20130530000085  ENKESHAFI  ARDALAN
# 1  1003000126  7517003643  I20130530000085  ENKESHAFI  ARDALAN
# 2  1003000126  7517003643  I20150824000105  ENKESHAFI  ARDALAN
# 3  1003000126  7517003643  I20150824000105  ENKESHAFI  ARDALAN
# 4  1003000126  7517003643  I20150824000105  ENKESHAFI  ARDALAN
#
#                full_nm gndr cred med_sch  grd_yr           pri_spec  \
# 0  ARDALAN  ENKESHAFI     M  NaN   OTHER  1994.0  INTERNAL MEDICINE
# 1  ARDALAN  ENKESHAFI     M  NaN   OTHER  1994.0  INTERNAL MEDICINE
# 2  ARDALAN  ENKESHAFI     M  NaN   OTHER  1994.0  INTERNAL MEDICINE
# 3  ARDALAN  ENKESHAFI     M  NaN   OTHER  1994.0  INTERNAL MEDICINE
# 4  ARDALAN  ENKESHAFI     M  NaN   OTHER  1994.0  INTERNAL MEDICINE
#
#   sec_spec_1 sec_spec_2 sec_spec_3 sec_spec_4 sec_spec_all  \
# 0        NaN        NaN        NaN        NaN          NaN
# 1        NaN        NaN        NaN        NaN          NaN
# 2        NaN        NaN        NaN        NaN          NaN
# 3        NaN        NaN        NaN        NaN          NaN
# 4        NaN        NaN        NaN        NaN          NaN
#
#                              org_lgl_nm    org_pac_id  num_org_mem  \
# 0   EMERGENCY MEDICINE ASSOCIATES PA PC  8.022915e+09        182.0
# 1   EMERGENCY MEDICINE ASSOCIATES PA PC  8.022915e+09        182.0
# 2   EMERGENCY MEDICINE ASSOCIATES PA PC  8.022915e+09        182.0
# 3  SOUTHEASTERN INTENSIVIST SERVICES PC  9.335152e+09        133.0
# 4  SOUTHEASTERN INTENSIVIST SERVICES PC  9.335152e+09        133.0
#
#                    adr_ln_1 adr_ln_2 ln_2_sprs                 cty  st  \
# 0        1850 TOWN CTR PKWY      NaN       NaN              RESTON  VA
# 1    1701 N GEORGE MASON DR      NaN       NaN           ARLINGTON  VA
# 2  24440 STONE SPRINGS BLVD      NaN       NaN              DULLES  VA
# 3   1401 JOHNSTON WILLIS DR      NaN       NaN  NORTH CHESTERFIELD  VA
# 4         411 W RANDOLPH RD      NaN       NaN            HOPEWELL  VA
#
#          zip     phn_numbr hosp_afl_1      hosp_afl_lbn_1 hosp_afl_2  \
# 0  201903219  7.036899e+09     490112  CJW MEDICAL CENTER     210028
# 1  222053610  7.035586e+09     490112  CJW MEDICAL CENTER     210028
# 2  201662247  5.713674e+09     490112  CJW MEDICAL CENTER     210028
# 3  232354730  8.044835e+09     490112  CJW MEDICAL CENTER     210028
# 4  238602938  8.045412e+09     490112  CJW MEDICAL CENTER     210028
#
#                   hosp_afl_lbn_2 hosp_afl_3 hosp_afl_lbn_3 hosp_afl_4  \
# 0  MEDSTAR SAINT MARY'S HOSPITAL        NaN            NaN        NaN
# 1  MEDSTAR SAINT MARY'S HOSPITAL        NaN            NaN        NaN
# 2  MEDSTAR SAINT MARY'S HOSPITAL        NaN            NaN        NaN
# 3  MEDSTAR SAINT MARY'S HOSPITAL        NaN            NaN        NaN
# 4  MEDSTAR SAINT MARY'S HOSPITAL        NaN            NaN        NaN
#
#   hosp_afl_lbn_4  hosp_afl_5 hosp_afl_lbn_5 assgn
# 0            NaN         NaN            NaN     Y
# 1            NaN         NaN            NaN     Y
# 2            NaN         NaN            NaN     Y
# 3            NaN         NaN            NaN     Y
# 4            NaN         NaN            NaN     Y

# %%
# export current data to CSV for future analysis
data.to_csv('physician_compare_national-updates-1.csv', index=False)
