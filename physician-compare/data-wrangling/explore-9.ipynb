# %% [markdown]
# # _Physician Compare National: Explore #9_
#
# This notebook is a continuation from of my analysis on the following data gathered via [Data.Medicare.gov](https://data.medicare.gov/Physician-Compare/Physician-Compare-National-Downloadable-File/mj5m-pzi6). It contains general information about individual eligible professionals (EPs) such as demographic information and Medicare quality program participation. This dataset is updated twice a month with the most current demographic information available at that time.
#
# # _Today's Goal(s)_
#
# Continue exploring how to loop through all the cities and extract the correct zip code for each one.

# %%
from datetime import datetime

# current date and time
now = datetime.now()

# timestamp to signify the beginning of work
print("Work started: ", now)
# Out:
# Work started:  2019-10-05 15:42:14.445020

# %%
# first thing we need to do --> load in the data
# import pandas
import pandas as pd
pd.options.display.max_columns = None
# %load_ext autoreload
# %autoreload 2

# import data from yesterday
data = pd.read_csv('physician_compare_national-updates-2.csv', low_memory=False);

# inspect the first five rows
data.head()
# Out:
#           npi  ind_pac_id      ind_enrl_id              full_nm gndr  \
# 0  1003000126  7517003643  I20130530000085  ARDALAN  ENKESHAFI     M
# 1  1003000126  7517003643  I20130530000085  ARDALAN  ENKESHAFI     M
# 2  1003000126  7517003643  I20150824000105  ARDALAN  ENKESHAFI     M
# 3  1003000126  7517003643  I20150824000105  ARDALAN  ENKESHAFI     M
# 4  1003000126  7517003643  I20150824000105  ARDALAN  ENKESHAFI     M
#
#          cred med_sch  grd_yr           pri_spec sec_spec_1 sec_spec_2  \
# 0  Not Listed   OTHER    1994  INTERNAL MEDICINE       None       None
# 1  Not Listed   OTHER    1994  INTERNAL MEDICINE       None       None
# 2  Not Listed   OTHER    1994  INTERNAL MEDICINE       None       None
# 3  Not Listed   OTHER    1994  INTERNAL MEDICINE       None       None
# 4  Not Listed   OTHER    1994  INTERNAL MEDICINE       None       None
#
#   sec_spec_3 sec_spec_4 sec_spec_all                            org_lgl_nm  \
# 0       None       None         None   EMERGENCY MEDICINE ASSOCIATES PA PC
# 1       None       None         None   EMERGENCY MEDICINE ASSOCIATES PA PC
# 2       None       None         None   EMERGENCY MEDICINE ASSOCIATES PA PC
# 3       None       None         None  SOUTHEASTERN INTENSIVIST SERVICES PC
# 4       None       None         None  SOUTHEASTERN INTENSIVIST SERVICES PC
#
#      org_pac_id  num_org_mem                   full_adr ln_2_sprs  \
# 0  8.022915e+09          182        1850 TOWN CTR PKWY          N
# 1  8.022915e+09          182    1701 N GEORGE MASON DR          N
# 2  8.022915e+09          182  24440 STONE SPRINGS BLVD          N
# 3  9.335152e+09          133   1401 JOHNSTON WILLIS DR          N
# 4  9.335152e+09          133         411 W RANDOLPH RD          N
#
#                   cty  st        zip     phn_numbr hosp_afl_1  \
# 0              RESTON  VA  201903219  7.036899e+09   490112.0
# 1           ARLINGTON  VA  222053610  7.035586e+09   490112.0
# 2              DULLES  VA  201662247  5.713674e+09   490112.0
# 3  NORTH CHESTERFIELD  VA  232354730  8.044835e+09   490112.0
# 4            HOPEWELL  VA  238602938  8.045412e+09   490112.0
#
#        hosp_afl_lbn_1 hosp_afl_2                 hosp_afl_lbn_2 hosp_afl_3  \
# 0  CJW MEDICAL CENTER   210028.0  MEDSTAR SAINT MARY'S HOSPITAL        NaN
# 1  CJW MEDICAL CENTER   210028.0  MEDSTAR SAINT MARY'S HOSPITAL        NaN
# 2  CJW MEDICAL CENTER   210028.0  MEDSTAR SAINT MARY'S HOSPITAL        NaN
# 3  CJW MEDICAL CENTER   210028.0  MEDSTAR SAINT MARY'S HOSPITAL        NaN
# 4  CJW MEDICAL CENTER   210028.0  MEDSTAR SAINT MARY'S HOSPITAL        NaN
#
#   hosp_afl_lbn_3 hosp_afl_4 hosp_afl_lbn_4  hosp_afl_5 hosp_afl_lbn_5 assgn
# 0            NaN        NaN            NaN         NaN            NaN     Y
# 1            NaN        NaN            NaN         NaN            NaN     Y
# 2            NaN        NaN            NaN         NaN            NaN     Y
# 3            NaN        NaN            NaN         NaN            NaN     Y
# 4            NaN        NaN            NaN         NaN            NaN     Y

# %%
# what are the unique lengths of the zip codes?
print('Length of zip codes take the following values: {}'.format(sorted(data['zip'].str.len().unique())))
# Out:
# Length of zip codes take the following values: [3, 4, 5, 7, 8, 9]

# %%
# what are the value counts for each length of the zip codes?
data['zip'].str.len().value_counts()
# Out:
# 9    2059140
# 8     132917
# 5      13060
# 7       3039
# 3       1710
# 4        924
# Name: zip, dtype: int64

# %%
# create subset of data where zip code is length 4
length_4 = data[data['zip'].str.len() == 4]; length_4.head(6)
# Out:
#              npi  ind_pac_id      ind_enrl_id            full_nm gndr  \
# 102   1003003088  4981791837  I20071025000015       AVANI  VORA     F
# 339   1003011065  4082888722  I20111115000827       LAURA M LEI     F
# 1183  1003030651  9739230780  I20161107000694      SALVA  BILAL     F
# 1242  1003033390  1759474927  I20070904000383     BRIAN C CAMBI     M
# 1462  1003041427  6103953765  I20100430000016   LAURIE A. FORTY     F
# 1578  1003043209   648424283  I20170517002241  MARJORIE E AFFEL     F
#
#             cred                                            med_sch  grd_yr  \
# 102   Not Listed                                              OTHER    2010
# 339   Not Listed                    UMDNJ-NEW JERSEY MEDICAL SCHOOL    2007
# 1183  Not Listed                                              OTHER    1996
# 1242  Not Listed  STATE UNIVERSITY OF NEW YORK AT BUFFALO SCHOOL...    1999
# 1462  Not Listed                                              OTHER    2007
# 1578  Not Listed                                              OTHER    2009
#
#                        pri_spec                           sec_spec_1  \
# 102            PHYSICAL THERAPY                                 None
# 339              ANESTHESIOLOGY                                 None
# 1183            FAMILY MEDICINE                                 None
# 1242  INTERVENTIONAL CARDIOLOGY  CARDIOVASCULAR DISEASE (CARDIOLOGY)
# 1462         NURSE PRACTITIONER                                 None
# 1578            FAMILY MEDICINE                                 None
#
#      sec_spec_2 sec_spec_3 sec_spec_4                         sec_spec_all  \
# 102        None       None       None                                 None
# 339        None       None       None                                 None
# 1183       None       None       None                                 None
# 1242       None       None       None  CARDIOVASCULAR DISEASE (CARDIOLOGY)
# 1462       None       None       None                                 None
# 1578       None       None       None                                 None
#
#                                     org_lgl_nm    org_pac_id  num_org_mem  \
# 102     JERSEY PHYSICAL THERAPY ASSOCIATES LLC  5.472403e+08            6
# 339   ANESTHESIA CONSULTANTS OF NEW JERSEY LLC  3.375449e+09           65
# 1183              ELLIOT PROFESSIONAL SERVICES  6.103728e+09          227
# 1242               NORTHEAST MEDICAL GROUP INC  1.254234e+09         1042
# 1462               COMMUNITY HEALTH CARE, INC.  9.335040e+09           42
# 1578               COMMUNITY HEALTH CARE, INC.  9.335040e+09           42
#
#                                 full_adr ln_2_sprs           cty  st   zip  \
# 102                       3228 ROUTE 27          N  KENDALL PARK  NJ  8824
# 339   SOMERSET MED CTR 110 REHILL AVENUE         N    SOMERVILLE  NJ  8876
# 1183                     ONE ELLIOT WAY          N    MANCHESTER  NH  3103
# 1242                196 PKWY S SUITE 103         N     WATERFORD  CT  6385
# 1462                       251 BROAD ST          N     BRIDGETON  NJ  8302
# 1578                       251 BROAD ST          N     BRIDGETON  NJ  8302
#
#          phn_numbr hosp_afl_1  \
# 102   7.322970e+09        NaN
# 339   9.086852e+09   310048.0
# 1183  6.036634e+09   300012.0
# 1242  8.604434e+09    70007.0
# 1462  8.564531e+09   310032.0
# 1578  8.564531e+09   310081.0
#
#                                          hosp_afl_lbn_1 hosp_afl_2  \
# 102                                                 NaN        NaN
# 339   ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL - SOME...        NaN
# 1183                                    ELLIOT HOSPITAL   300034.0
# 1242                       LAWRENCE & MEMORIAL HOSPITAL    70022.0
# 1462                    INSPIRA MEDICAL CENTER VINELAND        NaN
# 1578                    INSPIRA MEDICAL CENTER WOODBURY        NaN
#
#                hosp_afl_lbn_2 hosp_afl_3     hosp_afl_lbn_3 hosp_afl_4  \
# 102                       NaN        NaN                NaN        NaN
# 339                       NaN        NaN                NaN        NaN
# 1183  CATHOLIC MEDICAL CENTER        NaN                NaN        NaN
# 1242  YALE-NEW HAVEN HOSPITAL   410013.0  WESTERLY HOSPITAL        NaN
# 1462                      NaN        NaN                NaN        NaN
# 1578                      NaN        NaN                NaN        NaN
#
#      hosp_afl_lbn_4  hosp_afl_5 hosp_afl_lbn_5 assgn
# 102             NaN         NaN            NaN     Y
# 339             NaN         NaN            NaN     Y
# 1183            NaN         NaN            NaN     Y
# 1242            NaN         NaN            NaN     Y
# 1462            NaN         NaN            NaN     Y
# 1578            NaN         NaN            NaN     Y

# %%
# reset index so numbers aren't off
length4 = length_4.reset_index(drop=True)

# %%
# load zip code library
from uszipcode import SearchEngine

# create search object for zip code look-up
search = SearchEngine(simple_zipcode=True)

# %%
# list for tuples
tuple_list = []

for row in length4[['cty', 'st']].head(15).itertuples(index=True, name=None):
    tuple_list.append(row)

# %%
tuple_list
# Out:
# [(0, 'KENDALL PARK', 'NJ'),
#  (1, 'SOMERVILLE', 'NJ'),
#  (2, 'MANCHESTER', 'NH'),
#  (3, 'WATERFORD', 'CT'),
#  (4, 'BRIDGETON', 'NJ'),
#  (5, 'BRIDGETON', 'NJ'),
#  (6, 'MAHWAH', 'NJ'),
#  (7, 'MAHWAH', 'NJ'),
#  (8, 'MAHWAH', 'NJ'),
#  (9, 'CONCORD', 'MA'),
#  (10, 'OAK BLUFFS', 'MA'),
#  (11, 'CAMBRIDGE', 'MA'),
#  (12, 'HYANNIS', 'MA'),
#  (13, 'MARSTON MILLS', 'MA'),
#  (14, 'MASHPEE', 'MA')]

# %%
# how to extract city name
print(tuple_list[0][1])

# how to extract state
print(tuple_list[0][2])
# Out:
# KENDALL PARK
# NJ

# %%
for tup in tuple_list:
    print(tup[1], tup[2])
# Out:
# KENDALL PARK NJ
# SOMERVILLE NJ
# MANCHESTER NH
# WATERFORD CT
# BRIDGETON NJ
# BRIDGETON NJ
# MAHWAH NJ
# MAHWAH NJ
# MAHWAH NJ
# CONCORD MA
# OAK BLUFFS MA
# CAMBRIDGE MA
# HYANNIS MA
# MARSTON MILLS MA
# MASHPEE MA

# %%
for tup in tuple_list:
    print(search.by_city_and_state(city=tup[1], state=tup[2])[0].to_dict()['zipcode'])
# Out:
# 08824
# 08876
# 03101
# 06385
# 08302
# 08302
# 07430
# 07430
# 07430
# 01742
# 02557
# 02138
# 02601
# 02648
# 02649

# %%
# same as above but with all rows
all_rows = []

for row in length4[['cty', 'st']].itertuples(index=True, name=None):
    all_rows.append(row)

# %%
# what is the length of all_rows?
print(len(all_rows))
# Out:
# 924

# %%
# make sure this worked, loop through last ~10 observations in list
for tup in all_rows[914:924]:
    print(tup[1], tup[2])
# Out:
# NEPTUNE NJ
# CHERRY HILL NJ
# WEST SPRINGFIELD MA
# CRANSTON RI
# SIMSBURY CT
# CUMBERLAND RI
# MORRISVILLE VT
# WESTFIELD NJ
# SCARBOROUGH ME
# BUCKSPORT ME

# %%
for tup in all_rows[914:924]:
    print(search.by_city_and_state(city=tup[1], state=tup[2])[0].to_dict()['zipcode'])
# Out:
# 07753
# 08002
# 01089
# 02910
# 06070
# 02864
# 05661
# 07090
# 04074
# 04416

# %%
for i in range(len(all_rows[900:])):
    print(search.by_city_and_state(city=tuple_list[i][1], state=tuple_list[i][2])[0].to_dict()['zipcode'])
# Out:
# 08824
# 08876
# 03101
# 06385
# 08302
# 08302
# 07430
# 07430
# 07430
# 01742
# 02557
# 02138
# 02601
# 02648
# 02649
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-67-1824c5ef0f9d> in <module>
#       1 for i in range(len(all_rows[900:])):
# ----> 2     print(search.by_city_and_state(city=tuple_list[i][1], state=tuple_list[i][2])[0].to_dict()['zipcode'])
#
# IndexError: list index out of range

# %%
import time
# create search object for zip code look-up
search = SearchEngine(simple_zipcode=True)

with SearchEngine(simple_zipcode=True) as search:
    for row in length4[['cty', 'st']].head(25).itertuples(index=True, name=None):
        print(search.by_city_and_state(city=row[1], state=row[2])[0].values()[0])
        time.sleep(1)
# Out:
# 08824
# 08876
# 03101
# 06385
# 08302
# 08302
# 07430
# 07430
# 07430
# 01742
# 02557
# 02138
# 02601
# 02648
# 02649
# 07722
# 08002
# 08102
# 08807
# 06426
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-79-85b8e8b02f61> in <module>
#       5 with SearchEngine(simple_zipcode=True) as search:
#       6     for row in length4[['cty', 'st']].head(25).itertuples(index=True, name=None):
# ----> 7         print(search.by_city_and_state(city=row[1], state=row[2])[0].values()[0])
#       8         time.sleep(1)
#
# IndexError: list index out of range

# %%
import time
# create search object for zip code look-up
search = SearchEngine(simple_zipcode=True)

with SearchEngine(simple_zipcode=True) as search:
    for n in range(len(length4.head(25))):
        print(search.by_city_and_state(city=length4.loc[n, 'cty'], state=length4.loc[n, 'st'])[0].values()[0])
        time.sleep(1)
# Out:
# 08824
# 08876
# 03101
# 06385
# 08302
# 08302
# 07430
# 07430
# 07430
# 01742
# 02557
# 02138
# 02601
# 02648
# 02649
# 07722
# 08002
# 08102
# 08807
# 06426
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-81-69e60ded505d> in <module>
#       5 with SearchEngine(simple_zipcode=True) as search:
#       6     for n in range(len(length4.head(25))):
# ----> 7         print(search.by_city_and_state(city=length4.loc[n, 'cty'], state=length4.loc[n, 'st'])[0].values()[0])
#       8         time.sleep(1)
#
# IndexError: list index out of range

# %%
# lets combine all these together and return the associated zip code for cty, st combo
all_zips = []

for tup in all_rows:
    z = search.by_city_and_state(city=tup[1], state=tup[2])[0].to_dict()['zipcode']
    all_zips.append(z)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-7234b8c3d338> in <module>
#       3
#       4 for tup in all_rows:
# ----> 5     z = search.by_city_and_state(city=tup[1], state=tup[2])[0].to_dict()['zipcode']
#       6     all_zips.append(z)
#
# IndexError: list index out of range

# %%
# define function that gathers city and state and returns zipcode info
def zipcode(row):
    zipcode = search.by_city_and_state(city=row['cty'], state=row['st'])[0].to_dict()['zipcode']
    return zipcode

# %%
# test to see if we can use apply with our recently defined function to get zipcode
length4.head().apply(zipcode, axis=1)
# Out:
# 0    08824
# 1    08876
# 2    03101
# 3    06385
# 4    08302
# dtype: object

# %%
# see if this will work on enture dataframe
length4.apply(zipcode, axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-65-848ef88bfa2c> in <module>
#       1 # see if this will work on enture dataframe
# ----> 2 length4.apply(zipcode, axis=1)
#
# ~/anaconda3/envs/geography/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~/anaconda3/envs/geography/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ~/anaconda3/envs/geography/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# ~/anaconda3/envs/geography/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# <ipython-input-62-c458ce271016> in zipcode(row)
#       1 # define function that gathers city and state and returns zipcode info
#       2 def zipcode(row):
# ----> 3     zipcode = search.by_city_and_state(city=row['cty'], state=row['st'])[0].to_dict()['zipcode']
#       4     return zipcode
#
# IndexError: ('list index out of range', 'occurred at index 20')

# %%
# current date and time
now = datetime.now()

# timestamp to signify the beginning of work
print("Work ended: ", now)
# Out:
# Work ended:  2019-10-05 17:09:23.716091
